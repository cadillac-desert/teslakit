# %% [markdown]
# ... ***CURRENTLY UNDER DEVELOPMENT*** ...

# %% [markdown]
# ## Obtain daily SLP predictor and associated wave conditions. Based on Camus et al. (2014), Hegermiller et al. (2017) and Rueda et al. (2017)
#
#
# inputs required:
#   * ESTELA fields for the site location
#   * SLP fields from CFSR reanalysis
#   * Wave families from *notebook 09*
#   * Historical TCs inside radio 14 from *notebook 05*
#
# in this notebook:
#   * Construct daily SLP predictor
#   * Obtain Daily Weather Types (DWT) and probabilities of occurrence
#   * Associate wave conditions to each DWT

# %% [markdown]
# ### Workflow:
#
# <div>
# <img src="resources/nb01_10.png" width="600px">
# </div>

# %% [markdown]
# ## Daily SLP predictor
# Weather is represented by sea level pressure (SLP) fields and the squared gradients (SLPG) of those fields obtained from the Climate Forecast System Reanalysis (CFSR) (Saha, et al., 2011). SLP fields effectively capture high- and low-pressure systems while SLPG are related to the strength of the wind stress generating waves and wind induced storm surge. Only the SLPs and SLPGs in a region considered to influence the site study are included in the analysis, however the size of the region extends to include distant weather systems due to the generation of swell which propagates across the ocean and affects the local wave runup.  **The region of influence was defined using the ESTELA**(Evaluation of Source and Travel-time of wave Energy reaching a Local Area) method (Perez et al., 2014), which identifies the relevant amount of energy directed along great circle arcs toward the study site using full directional wave spectra in the global IFREMER wave hindcast (Rascle & Ardhuin, 2013).
# The SLP and SLPG fields were further modified to consider the travel time of swell waves, which arrive to the study site on the order of days to weeks after generation by a distant weather system. An atmospheric predictor,  $P_t$ , was created dependent on the isochrones of average wave travel time identified by ESTELA:
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$P_t = \{...,{SLP}_{t-i+1,\Omega i},{SLPG}_{t-i+1,\Omega i}...\}$ for $i =1,...,p$;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# where $\Omega_i$ represents the spatial domain between the daily isochrones $i - 1$ and $\textit{i}$, and $\textit{p}$ is the number of days of the last isochrone predicted by ESTELA, which represents the longest possible wave propagation time from generation until arrival at the target location.
#
# Weather-typing of the PCs of P_(t,x,y) was performed at a daily time scale to create a daily weather type (DWT) as a proxy for synoptic SLP patterns (Camus et al., 2014a, Camus et al. 2016). The number of clusters in this analysis was set at 36, and the regression guided K-means was performed iteratively until every cluster contained at least *50* days. Remapping the centroids of each cluster from PC space to SLP space results in the original DWT (figures below). Six additional DWTs were created to represent tropical depressions and tropical cyclone (TC) categories 1 through 5 by removing days with TC generation from the K-means clusters (*ESTELA Predictor - Add Historical TCs*) (TC generation defined in *notebook 05*). Separating the TCs as explicit categorical variables ensured that the probabilities of occurrence and conditional dependencies of the rare events were persevered in the framework rather than being clustered into extra-tropical synoptic circulation patterns as the most distance points from a prescribed centroid.
#
# The 42 DWTs are presented in the figures below *(ESTELA Predictor - KMeans Classification)* as a matrix analogous to a self-organized map (Sheridan & Lee, 2011) to ensure that DWTs with similar spatial patterns are graphically presented adjacent to each other. *Plot DWTs Probabilities* and *DWTs probabilities conditioned to IWT and AWT* demonstrate how DWTs have historically exhibited conditional dependencies on the state of large-scale climate phenomena. The most readily discernable conditional dependencies are on seasonal scales where most DWTs exhibit a high probability of occurrence during a particular season and zero chance of occurring at other times. Although DWT dependencies on IWTs and AWTs are not as stark, probabilities of daily weather are still clearly affected, most notably with difference between the extremes of El Nino/La Nina and when the MJO is located on opposite sides of the globe.
#
# ## Daily predictand
#
# The DWT’s associated sea-state parameter distributions is provided at the end of the notebook to confirm how the automated identification of atmospheric variability also delineated variability within the local TWL components.  The distributions of the three wave systems identified in *notebook 09* conditioned to each DWT are shown.
#
# ## Intradaily Hydrographs
#
# Associating each synthetic iteration of climate with hypothetical local environmental parameters is a multi-step process which emphasizes preservation of joint probabilities across multiple variables while maintaining flexibility for high dimensionality. The methodology is based on the concept of that sequences of consecutive daily weather typically contain the same synoptic weather system, and that the potential for flooding is maximized as some point during that weather system. In the automated classification of DWTs, this spatial correlation results in several days in a row often being assigned the same representative cluster.  Consecutive days of the same DWT are considered in this study to be a single weather system approaching and passing over the study site, with associated ramp-up and ramp down of sea-state parameters conditioned to a TWLproxy (figure below).
# All sea-state parameters at the time of maximum TWLproxy during each hydrograph were used to create distributions unique to each DWT. The idealized sketch in the figure below demonstrates that this approach does not always identify the maximum value of each parameter (which often occur at different times, e.g., Serafin and Ruggiero, 2014). Instead the goal here is to preserve physically realistic joint dependence of sea-state parameters, while reducing the problem to a parameter independent of the deterministic tides.
#
# <div>
# <img src="resources/nb01_10_intradaily.png" width="400px">
# </div>

# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# common
import os
import os.path as op

# for user inputs
import tkinter as tk
from tkinter import filedialog
from tkinter import simpledialog

# pip
import numpy as np
import xarray as xr

import matplotlib.pyplot as plt

# for input configuration
import sys
sys.path.append('../../..')  # Appending parent directory to Python path
from input_configuration import *

# DEV: override installed teslakit
import sys
sys.path.insert(0, op.join(os.path.abspath(''), '..', '..', '..'))

# teslakit 
from teslakit.database import Database
from teslakit.estela import spatial_gradient, Predictor
from teslakit.util.time_operations import xds_common_dates_daily

from teslakit.plotting.estela import Plot_ESTELA
from teslakit.plotting.wts import Plot_Probs_WT_WT, Plot_Probs_WT_WT_anomaly
from teslakit.plotting.waves import Plot_Waves_DWTs, Plot_DWTs_FamiliesPopulation

# %% [markdown]
# ## Database and Site parameters

# %%
# Teslakit database

p_data = p_data_input
db = Database(p_data)

# make a new site
db.MakeNewSite(site_name)
# Out:
# Teslakit Site already exists at C:/Users/fergusonpc/Teslakit-SF-Final\sites\SF

# %%
# --------------------------------------
# load data and set parameters

ESTELA = db.Load_ESTELA_data()            # ESTELA D data
SLP = db.Load_ESTELA_SLP()                # ESTELA Sea Level Pressure

WAVES = db.Load_WAVES_hist()              # Historical gow/csiro waves point

# KMA REGRESSION GUIDED parameters
kma_date_ini = '1979-01-01'
kma_date_end = '2018-12-31'

num_clusters = 36
kmarg_alpha = 0.3

# %% [markdown]
# ## ESTELA Predictor - Sea Level Pressure and Gradient

# %%
# --------------------------------------
# Plot ESTELA and wave point coordinates

mask_plot = ESTELA.mask_e95

Plot_ESTELA(
    ESTELA.pnt_longitude, ESTELA.pnt_latitude,
    ESTELA.F_y1993to2012 * mask_plot, 
    ESTELA.D_y1993to2012 * mask_plot,
    lon1 = 110, lon2 = 290, lat1 = -10, lat2 = 60,
);
# Out:
# basemap module required.

# %%
# --------------------------------------
# ESTELA waves data: calculate Fe, resample to daily

# calculate Fe
WAVES['Fe'] = (WAVES.Hs**2 * WAVES.Tp)**(1.0/3)

# select time window and calculate daily mean
WAVES_d = WAVES.sel(time = slice(kma_date_ini, kma_date_end)).resample(time='1D').mean()
    
print(WAVES_d)
# Out:
# <xarray.Dataset>
# Dimensions:      (time: 14610)
# Coordinates:
#   * time         (time) datetime64[ns] 1979-01-01 1979-01-02 ... 2018-12-31
# Data variables:
#     Hs           (time) float64 0.3691 0.6582 1.175 1.815 ... 1.979 3.129 2.686
#     Tp           (time) float64 3.258 4.118 8.125 10.22 ... 13.2 15.14 13.86
#     Dir          (time) float64 215.7 109.3 200.5 222.5 ... 284.7 280.5 287.6
#     sea_Hs       (time) float64 0.4736 0.8355 0.9704 1.826 ... 1.572 1.959 3.257
#     sea_Tp       (time) float64 3.075 4.054 5.539 8.895 ... 7.99 7.24 10.52
#     sea_Dir      (time) float64 178.6 94.54 133.6 191.0 ... 315.0 316.0 313.7
#     swell_1_Hs   (time) float64 nan 0.58 1.287 1.852 ... 0.2329 0.2152 0.1924
#     swell_1_Tp   (time) float64 nan 5.49 9.07 9.165 ... 15.1 14.07 13.5 14.9
#     swell_1_Dir  (time) float64 nan 176.8 202.7 195.0 ... 199.9 204.6 196.3
#     swell_2_Hs   (time) float64 0.3241 0.1454 0.2504 0.726 ... 2.455 2.039 1.688
#     swell_2_Tp   (time) float64 4.135 5.647 10.64 11.41 ... 12.67 15.13 13.04
#     swell_2_Dir  (time) float64 324.4 318.8 246.4 268.6 ... 300.4 294.7 298.5
#     TC_category  (time) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     Fe           (time) float64 0.7782 1.21 2.236 3.215 ... 3.723 5.289 4.637

# %% [markdown]
# ## ESTELA Predictor - Principal Component Analysis

# %%
#this code updates the .nc files for data and pca

# --------------------------------------
# Calculate ESTELA PCA

# select ESTELA at site grid
ESTELA_site = ESTELA.sel(longitude = SLP.longitude, latitude = SLP.latitude)
estela_D = ESTELA_site.D_y1993to2012

# estela masks: data mask (95% energy) and land mask (plots)
estela_mask = ESTELA_site.mask_e95  
estela_land = ESTELA_site.mask_land

SLP_d = SLP.sel(time = slice(kma_date_ini, kma_date_end))
SLP_d['mask_land'] = estela_land
SLP_d['SLP'] = SLP.SLP
SLP_d['SLP_gradient'] = SLP.GRD

# Use our custom ESTELA Predictor 
pred = Predictor(db.paths.site.ESTELA.pred_slp)
pred.data = SLP_d

# PCA (dynamic estela predictor)
pred.Calc_PCA_EstelaPred('SLP', estela_D)

print(pred.PCA)
# Out:
# <xarray.Dataset>
# Dimensions:        (n_components: 1992, n_features: 1992, n_lat: 29, n_lon: 74, n_points: 4292, time: 14590)
# Dimensions without coordinates: n_components, n_features, n_lat, n_lon, n_points, time
# Data variables:
#     PCs            (time, n_components) float64 -0.327 -9.163 ... -0.001427
#     EOFs           (n_components, n_features) float64 0.01938 ... 6.531e-06
#     variance       (n_components) float64 249.7 150.5 ... 1.072e-06 7.85e-07
#     pred_mean      (n_features) float64 1.014e+03 1.014e+03 ... 13.83 11.69
#     pred_std       (n_features) float64 5.666 5.202 5.627 ... 13.65 14.33 10.0
#     pred_lon       (n_lon) float64 142.0 144.0 146.0 148.0 ... 284.0 286.0 288.0
#     pred_lat       (n_lat) float64 0.0 2.0 4.0 6.0 8.0 ... 50.0 52.0 54.0 56.0
#     pred_time      (time) datetime64[ns] 1979-01-21 1979-01-22 ... 2018-12-31
#     pred_data_pos  (n_points) bool False False False False ... False False False
# Attributes:
#     method:     gradient + estela
#     pred_name:  SLP
# <xarray.Dataset>
# Dimensions:        (n_components: 1992, n_features: 1992, n_lat: 29, n_lon: 74, n_points: 4292, time: 14590)
# Dimensions without coordinates: n_components, n_features, n_lat, n_lon, n_points, time
# Data variables:
#     PCs            (time, n_components) float64 -0.327 -9.163 ... -0.001427
#     EOFs           (n_components, n_features) float64 0.01938 ... 6.531e-06
#     variance       (n_components) float64 249.7 150.5 ... 1.072e-06 7.85e-07
#     pred_mean      (n_features) float64 1.014e+03 1.014e+03 ... 13.83 11.69
#     pred_std       (n_features) float64 5.666 5.202 5.627 ... 13.65 14.33 10.0
#     pred_lon       (n_lon) float64 142.0 144.0 146.0 148.0 ... 284.0 286.0 288.0
#     pred_lat       (n_lat) float64 0.0 2.0 4.0 6.0 8.0 ... 50.0 52.0 54.0 56.0
#     pred_time      (time) datetime64[ns] 1979-01-21 1979-01-22 ... 2018-12-31
#     pred_data_pos  (n_points) bool False False False False ... False False False
# Attributes:
#     method:     gradient + estela
#     pred_name:  SLP

# %%
print(pred.data)
# Out:
# <xarray.Dataset>
# Dimensions:       (latitude: 29, longitude: 74, time: 14610)
# Coordinates:
#   * time          (time) datetime64[ns] 1979-01-01 1979-01-02 ... 2018-12-31
#   * latitude      (latitude) float64 0.0 2.0 4.0 6.0 8.0 ... 50.0 52.0 54.0 56.0
#   * longitude     (longitude) float64 142.0 144.0 146.0 ... 284.0 286.0 288.0
# Data variables:
#     SLP           (time, latitude, longitude) float64 ...
#     GRD           (time, latitude, longitude) float64 ...
#     mask_land     (latitude, longitude) float64 1.0 1.0 1.0 1.0 ... nan nan nan
#     SLP_gradient  (time, latitude, longitude) float64 ...

# %%
del pred.data

# %%
# Load predictor PCA, KMA if already calc'd
pred = Predictor(db.paths.site.ESTELA.pred_slp)

pred.Load()

print(pred.PCA)
# Out:
# <xarray.Dataset>
# Dimensions:        (n_components: 1992, n_features: 1992, n_lat: 29, n_lon: 74, n_points: 4292, time: 14590)
# Dimensions without coordinates: n_components, n_features, n_lat, n_lon, n_points, time
# Data variables:
#     PCs            (time, n_components) float64 ...
#     EOFs           (n_components, n_features) float64 ...
#     variance       (n_components) float64 ...
#     pred_mean      (n_features) float64 ...
#     pred_std       (n_features) float64 ...
#     pred_lon       (n_lon) float64 ...
#     pred_lat       (n_lat) float64 ...
#     pred_time      (time) datetime64[ns] ...
#     pred_data_pos  (n_points) bool ...
# Attributes:
#     method:     gradient + estela
#     pred_name:  SLP

# %%
# plot PCA EOFs
n_EOFs = 3

pred.Plot_EOFs_EstelaPred(n_EOFs, show=True);
# Out:
# <xarray.Dataset>
# Dimensions:        (n_components: 1992, n_features: 1992, n_lat: 29, n_lon: 74, n_points: 4292, time: 14590)
# Dimensions without coordinates: n_components, n_features, n_lat, n_lon, n_points, time
# Data variables:
#     PCs            (time, n_components) float64 ...
#     EOFs           (n_components, n_features) float64 ...
#     variance       (n_components) float64 ...
#     pred_mean      (n_features) float64 ...
#     pred_std       (n_features) float64 ...
#     pred_lon       (n_lon) float64 ...
#     pred_lat       (n_lat) float64 ...
#     pred_time      (time) datetime64[ns] ...
#     pred_data_pos  (n_points) bool ...
# Attributes:
#     method:     gradient + estela
#     pred_name:  SLP

# %% [markdown]
# ## ESTELA Predictor - KMeans Classification

# %%
# Calculate KMA (regression guided with WAVES data)
pred.Calc_KMA_regressionguided(
    num_clusters,
    WAVES_d, ['Hs','Tp','Fe'],
    kmarg_alpha, min_group_size=60,
)
# Out:
#   c: 26 - s: 43
#   c: 28 - s: 36
#   c: 34 - s: 13
#   c: 35 - s: 9
# total attemps:  1
#
#   c: 17 - s: 6
#   c: 19 - s: 51
#   c: 23 - s: 22
#   c: 29 - s: 14
#   c: 35 - s: 44
# total attemps:  2
#
#   c: 9 - s: 24
#   c: 10 - s: 11
#   c: 13 - s: 40
#   c: 25 - s: 10
#   c: 26 - s: 14
#   c: 32 - s: 9
#   c: 34 - s: 12
# total attemps:  3
#
#   c: 5 - s: 51
#   c: 17 - s: 14
#   c: 18 - s: 25
#   c: 20 - s: 13
#   c: 28 - s: 31
#   c: 34 - s: 8
# total attemps:  4
#
#   c: 1 - s: 42
#   c: 12 - s: 20
# total attemps:  5
#
#   c: 9 - s: 49
#   c: 30 - s: 19
#   c: 35 - s: 34
# total attemps:  6
#
#   c: 6 - s: 40
#   c: 25 - s: 6
#   c: 28 - s: 6
#   c: 34 - s: 35
# total attemps:  7
#
#   c: 8 - s: 3
#   c: 21 - s: 58
#   c: 31 - s: 31
# total attemps:  8
#
#   c: 4 - s: 11
#   c: 7 - s: 23
#   c: 18 - s: 14
#   c: 23 - s: 35
#   c: 26 - s: 15
#   c: 30 - s: 5
#   c: 34 - s: 20
#   c: 35 - s: 32
# total attemps:  9
#
#   c: 8 - s: 5
#   c: 9 - s: 4
#   c: 25 - s: 35
#   c: 33 - s: 54
#   c: 35 - s: 26
# total attemps:  10
#
#   c: 4 - s: 58
#   c: 6 - s: 14
#   c: 10 - s: 46
#   c: 13 - s: 26
#   c: 18 - s: 23
#   c: 20 - s: 25
#   c: 22 - s: 13
#   c: 28 - s: 29
#   c: 29 - s: 34
# total attemps:  11
#
#   c: 2 - s: 47
#   c: 3 - s: 11
#   c: 10 - s: 48
#   c: 16 - s: 6
#   c: 24 - s: 55
#   c: 27 - s: 7
#   c: 33 - s: 6
#   c: 34 - s: 38
# total attemps:  12
#
#   c: 20 - s: 35
#   c: 21 - s: 4
#   c: 25 - s: 17
#   c: 26 - s: 4
#   c: 27 - s: 5
#   c: 28 - s: 20
#   c: 30 - s: 36
#   c: 32 - s: 38
#   c: 35 - s: 44
# total attemps:  13
#
#   c: 3 - s: 14
#   c: 13 - s: 8
#   c: 15 - s: 51
#   c: 16 - s: 7
#   c: 17 - s: 4
#   c: 18 - s: 4
#   c: 19 - s: 5
#   c: 20 - s: 7
#   c: 22 - s: 51
#   c: 24 - s: 10
#   c: 34 - s: 26
#   c: 35 - s: 31
# total attemps:  14
#
#   c: 8 - s: 6
#   c: 15 - s: 6
#   c: 19 - s: 4
#   c: 20 - s: 4
#   c: 22 - s: 5
#   c: 23 - s: 9
#   c: 27 - s: 38
#   c: 33 - s: 14
#   c: 35 - s: 3
# total attemps:  15
#
#   c: 7 - s: 25
#   c: 18 - s: 43
#   c: 23 - s: 55
#   c: 27 - s: 23
#   c: 28 - s: 41
# total attemps:  16
#
#   c: 2 - s: 12
#   c: 12 - s: 9
#   c: 15 - s: 20
#   c: 17 - s: 31
#   c: 19 - s: 13
#   c: 25 - s: 3
#   c: 28 - s: 14
#   c: 32 - s: 14
#   c: 33 - s: 10
#   c: 35 - s: 3
# total attemps:  17
#
#   c: 1 - s: 39
#   c: 11 - s: 43
#   c: 16 - s: 14
#   c: 21 - s: 18
#   c: 22 - s: 3
#   c: 28 - s: 30
#   c: 29 - s: 8
#   c: 30 - s: 59
#   c: 35 - s: 57
# total attemps:  18
#
#   c: 6 - s: 26
#   c: 12 - s: 6
#   c: 35 - s: 43
# total attemps:  19
#
#   c: 0 - s: 5
#   c: 3 - s: 24
#   c: 11 - s: 17
#   c: 14 - s: 8
#   c: 23 - s: 7
#   c: 25 - s: 6
#   c: 27 - s: 19
#   c: 29 - s: 12
#   c: 31 - s: 5
#   c: 35 - s: 13
# total attemps:  20
#
#   c: 6 - s: 42
#   c: 8 - s: 27
#   c: 21 - s: 49
#   c: 34 - s: 11
# total attemps:  21
#
#   c: 7 - s: 5
#   c: 8 - s: 11
#   c: 19 - s: 11
#   c: 23 - s: 21
#   c: 25 - s: 12
#   c: 31 - s: 30
#   c: 32 - s: 9
#   c: 35 - s: 47
# total attemps:  22
#
#   c: 17 - s: 51
#   c: 23 - s: 19
#   c: 31 - s: 37
# total attemps:  23
#
#   c: 0 - s: 49
#   c: 5 - s: 59
#   c: 6 - s: 3
#   c: 7 - s: 42
#   c: 20 - s: 4
#   c: 23 - s: 4
#   c: 26 - s: 2
#   c: 28 - s: 7
# total attemps:  24
#
#   c: 0 - s: 5
#   c: 1 - s: 19
#   c: 8 - s: 9
#   c: 17 - s: 8
#   c: 20 - s: 4
#   c: 25 - s: 3
#   c: 30 - s: 22
#   c: 31 - s: 15
#   c: 32 - s: 50
#   c: 33 - s: 8
#   c: 35 - s: 4
# total attemps:  25
#
#   c: 0 - s: 10
#   c: 12 - s: 22
#   c: 13 - s: 6
#   c: 16 - s: 36
#   c: 28 - s: 7
#   c: 29 - s: 36
#   c: 30 - s: 50
#   c: 31 - s: 6
#   c: 32 - s: 9
#   c: 33 - s: 9
#   c: 34 - s: 24
# total attemps:  26
#
#   c: 2 - s: 23
#   c: 6 - s: 4
#   c: 9 - s: 13
#   c: 10 - s: 17
#   c: 11 - s: 15
#   c: 18 - s: 16
#   c: 22 - s: 25
#   c: 23 - s: 10
#   c: 24 - s: 8
#   c: 26 - s: 7
#   c: 31 - s: 9
#   c: 32 - s: 4
#   c: 33 - s: 42
#   c: 34 - s: 25
# total attemps:  27
#
#   c: 19 - s: 7
#   c: 28 - s: 5
#   c: 30 - s: 49
# total attemps:  28
#
#   c: 0 - s: 41
#   c: 13 - s: 40
#   c: 14 - s: 10
#   c: 28 - s: 36
# total attemps:  29
#
#   c: 16 - s: 47
#   c: 27 - s: 5
# total attemps:  30
#
#   c: 4 - s: 39
#   c: 6 - s: 22
#   c: 9 - s: 5
#   c: 18 - s: 8
#   c: 19 - s: 7
#   c: 21 - s: 32
#   c: 24 - s: 9
#   c: 25 - s: 10
#   c: 28 - s: 16
#   c: 29 - s: 27
#   c: 32 - s: 30
# total attemps:  31
#
#   c: 2 - s: 4
#   c: 9 - s: 2
#   c: 10 - s: 16
#   c: 12 - s: 5
#   c: 24 - s: 28
#   c: 34 - s: 44
#   c: 35 - s: 5
# total attemps:  32
#
#   c: 11 - s: 6
#   c: 16 - s: 7
#   c: 19 - s: 11
#   c: 20 - s: 3
#   c: 21 - s: 48
# total attemps:  33
#
#   c: 4 - s: 3
#   c: 20 - s: 15
#   c: 22 - s: 47
# total attemps:  34
#
#   c: 7 - s: 3
#   c: 16 - s: 15
#   c: 17 - s: 9
#   c: 21 - s: 16
#   c: 34 - s: 6
# total attemps:  35
#
#   c: 9 - s: 6
#   c: 14 - s: 3
#   c: 16 - s: 14
#   c: 17 - s: 32
#   c: 19 - s: 54
#   c: 22 - s: 17
#   c: 25 - s: 32
#   c: 26 - s: 6
#   c: 30 - s: 44
#   c: 35 - s: 24
# total attemps:  36
#
#   c: 13 - s: 52
#   c: 24 - s: 4
#   c: 28 - s: 46
#   c: 30 - s: 15
# total attemps:  37
#
#   c: 16 - s: 59
#   c: 26 - s: 30
#   c: 35 - s: 7
# total attemps:  38
#
#   c: 27 - s: 27
#   c: 28 - s: 8
#   c: 34 - s: 22
#   c: 35 - s: 8
# total attemps:  39
#
#   c: 15 - s: 28
# total attemps:  40
#
#   c: 0 - s: 47
#   c: 24 - s: 6
#   c: 32 - s: 33
# total attemps:  41
#
#   c: 0 - s: 9
#   c: 5 - s: 49
#   c: 10 - s: 58
#   c: 20 - s: 17
#   c: 22 - s: 6
#   c: 26 - s: 45
#   c: 30 - s: 40
#   c: 31 - s: 3
#   c: 32 - s: 31
#   c: 33 - s: 7
# total attemps:  42
#
#   c: 5 - s: 19
#   c: 8 - s: 18
#   c: 10 - s: 47
#   c: 17 - s: 3
#   c: 18 - s: 54
#   c: 20 - s: 6
#   c: 23 - s: 22
#   c: 24 - s: 11
#   c: 28 - s: 19
#   c: 30 - s: 12
# total attemps:  43
#
#   c: 5 - s: 5
#   c: 11 - s: 26
#   c: 14 - s: 5
#   c: 17 - s: 45
#   c: 21 - s: 6
#   c: 23 - s: 3
#   c: 24 - s: 17
#   c: 25 - s: 12
#   c: 29 - s: 14
#   c: 31 - s: 11
#   c: 33 - s: 25
#   c: 35 - s: 10
# total attemps:  44
#
#   c: 8 - s: 4
#   c: 9 - s: 6
#   c: 13 - s: 7
#   c: 21 - s: 6
#   c: 23 - s: 9
#   c: 25 - s: 17
#   c: 26 - s: 5
#   c: 27 - s: 39
#   c: 29 - s: 2
#   c: 30 - s: 3
#   c: 31 - s: 14
#   c: 33 - s: 10
# total attemps:  45
#
#   c: 2 - s: 13
#   c: 8 - s: 31
#   c: 13 - s: 6
#   c: 14 - s: 24
#   c: 16 - s: 27
#   c: 17 - s: 15
#   c: 27 - s: 57
#   c: 28 - s: 49
#   c: 30 - s: 12
#   c: 32 - s: 27
# total attemps:  46
#
#   c: 1 - s: 50
#   c: 18 - s: 12
#   c: 20 - s: 8
#   c: 21 - s: 29
#   c: 32 - s: 36
# total attemps:  47
#
#   c: 3 - s: 11
#   c: 7 - s: 12
#   c: 25 - s: 20
#   c: 27 - s: 57
#   c: 31 - s: 9
#   c: 32 - s: 4
#   c: 34 - s: 5
# total attemps:  48
#
#   c: 12 - s: 8
#   c: 13 - s: 4
#   c: 14 - s: 4
#   c: 16 - s: 4
#   c: 18 - s: 55
#   c: 20 - s: 3
#   c: 22 - s: 6
#   c: 23 - s: 43
#   c: 26 - s: 10
#   c: 28 - s: 3
#   c: 29 - s: 31
# total attemps:  49
#
#   c: 18 - s: 15
#   c: 19 - s: 4
# total attemps:  50
#
#   c: 0 - s: 14
#   c: 14 - s: 5
#   c: 21 - s: 34
#   c: 24 - s: 15
#   c: 27 - s: 51
#   c: 34 - s: 22
# total attemps:  51
#
#   c: 7 - s: 7
#   c: 8 - s: 27
#   c: 9 - s: 2
#   c: 10 - s: 12
#   c: 16 - s: 9
#   c: 17 - s: 11
#   c: 19 - s: 13
#   c: 21 - s: 24
#   c: 23 - s: 12
#   c: 25 - s: 10
#   c: 26 - s: 58
#   c: 29 - s: 42
#   c: 32 - s: 19
#   c: 34 - s: 5
# total attemps:  52
#
#   c: 0 - s: 31
#   c: 17 - s: 12
#   c: 22 - s: 33
#   c: 33 - s: 33
#   c: 35 - s: 26
# total attemps:  53
#
#   c: 0 - s: 9
#   c: 3 - s: 25
#   c: 17 - s: 21
#   c: 20 - s: 2
#   c: 26 - s: 12
#   c: 27 - s: 34
#   c: 28 - s: 27
#   c: 33 - s: 12
#   c: 35 - s: 22
# total attemps:  54
#
#   c: 2 - s: 4
#   c: 5 - s: 5
#   c: 10 - s: 5
#   c: 17 - s: 58
#   c: 18 - s: 16
#   c: 19 - s: 6
#   c: 21 - s: 21
#   c: 29 - s: 10
#   c: 30 - s: 12
#   c: 32 - s: 4
#   c: 33 - s: 29
# total attemps:  55
#
#   c: 0 - s: 7
#   c: 5 - s: 17
#   c: 20 - s: 9
#   c: 21 - s: 14
#   c: 27 - s: 12
#   c: 29 - s: 6
#   c: 30 - s: 5
#   c: 32 - s: 31
#   c: 33 - s: 7
# total attemps:  56
#
#   c: 0 - s: 17
#   c: 7 - s: 32
#   c: 13 - s: 9
#   c: 19 - s: 10
#   c: 24 - s: 12
#   c: 26 - s: 13
#   c: 29 - s: 44
#   c: 31 - s: 34
#   c: 33 - s: 12
#   c: 35 - s: 25
# total attemps:  57
#
#   c: 20 - s: 37
#   c: 35 - s: 5
# total attemps:  58
#
#   c: 4 - s: 9
#   c: 10 - s: 6
#   c: 16 - s: 18
#   c: 23 - s: 53
#   c: 27 - s: 7
#   c: 29 - s: 11
#   c: 30 - s: 28
# total attemps:  59
#
#   c: 0 - s: 19
#   c: 8 - s: 17
#   c: 12 - s: 16
#   c: 20 - s: 7
#   c: 21 - s: 7
#   c: 24 - s: 36
#   c: 26 - s: 9
#   c: 29 - s: 5
#   c: 30 - s: 11
#   c: 32 - s: 3
#   c: 34 - s: 13
# total attemps:  60
#
#   c: 6 - s: 13
#   c: 12 - s: 12
#   c: 16 - s: 19
#   c: 22 - s: 14
#   c: 25 - s: 9
#   c: 27 - s: 14
#   c: 28 - s: 32
#   c: 29 - s: 8
#   c: 31 - s: 9
#   c: 32 - s: 46
#   c: 33 - s: 18
#   c: 34 - s: 13
#   c: 35 - s: 8
# total attemps:  61
#
#   c: 26 - s: 5
#   c: 27 - s: 18
#   c: 32 - s: 27
# total attemps:  62
#
#   c: 1 - s: 44
#   c: 7 - s: 7
#   c: 13 - s: 3
#   c: 15 - s: 8
#   c: 17 - s: 54
#   c: 24 - s: 26
#   c: 27 - s: 26
#   c: 30 - s: 7
#   c: 31 - s: 35
# total attemps:  63
#
#   c: 0 - s: 12
#   c: 1 - s: 5
#   c: 21 - s: 34
#   c: 24 - s: 48
#   c: 25 - s: 15
#   c: 27 - s: 53
#   c: 30 - s: 28
#   c: 32 - s: 27
# total attemps:  64
#
#   c: 9 - s: 15
#   c: 12 - s: 44
#   c: 15 - s: 30
# total attemps:  65
#
#   c: 0 - s: 4
#   c: 1 - s: 13
#   c: 4 - s: 22
#   c: 9 - s: 16
#   c: 20 - s: 3
#   c: 24 - s: 36
#   c: 27 - s: 11
#   c: 28 - s: 32
#   c: 30 - s: 7
#   c: 33 - s: 32
#   c: 35 - s: 58
# total attemps:  66
#
#   c: 0 - s: 29
#   c: 2 - s: 35
#   c: 4 - s: 56
#   c: 7 - s: 40
#   c: 29 - s: 14
#   c: 30 - s: 15
#   c: 34 - s: 47
# total attemps:  67
#
#   c: 2 - s: 33
#   c: 5 - s: 11
#   c: 10 - s: 20
#   c: 12 - s: 28
#   c: 14 - s: 56
#   c: 15 - s: 7
#   c: 19 - s: 26
#   c: 23 - s: 12
#   c: 24 - s: 7
#   c: 25 - s: 24
#   c: 26 - s: 13
#   c: 28 - s: 12
#   c: 29 - s: 14
#   c: 35 - s: 23
# total attemps:  68
#
#   c: 1 - s: 9
#   c: 7 - s: 37
#   c: 11 - s: 19
#   c: 12 - s: 27
#   c: 13 - s: 10
#   c: 15 - s: 5
#   c: 23 - s: 32
#   c: 24 - s: 4
#   c: 26 - s: 12
#   c: 28 - s: 8
#   c: 31 - s: 5
#   c: 34 - s: 3
#   c: 35 - s: 10
# total attemps:  69
#
#   c: 7 - s: 5
#   c: 12 - s: 49
#   c: 13 - s: 2
#   c: 20 - s: 25
#   c: 21 - s: 6
#   c: 27 - s: 53
#   c: 28 - s: 10
#   c: 29 - s: 32
#   c: 31 - s: 17
#   c: 33 - s: 6
# total attemps:  70
#
#   c: 5 - s: 36
#   c: 7 - s: 7
#   c: 12 - s: 17
#   c: 13 - s: 12
#   c: 17 - s: 18
#   c: 22 - s: 3
#   c: 25 - s: 26
#   c: 28 - s: 14
#   c: 30 - s: 8
#   c: 33 - s: 43
#   c: 34 - s: 30
#   c: 35 - s: 18
# total attemps:  71
#
#   c: 7 - s: 23
#   c: 14 - s: 19
#   c: 23 - s: 23
#   c: 30 - s: 8
# total attemps:  72
#
#   c: 0 - s: 59
#   c: 8 - s: 2
#   c: 33 - s: 14
# total attemps:  73
#
#   c: 0 - s: 14
#   c: 4 - s: 22
#   c: 9 - s: 13
#   c: 12 - s: 28
#   c: 13 - s: 42
#   c: 14 - s: 38
#   c: 18 - s: 21
#   c: 20 - s: 39
#   c: 24 - s: 9
#   c: 26 - s: 47
#   c: 28 - s: 21
#   c: 29 - s: 10
#   c: 32 - s: 40
#   c: 34 - s: 17
#   c: 35 - s: 50
# total attemps:  74
#
#   c: 17 - s: 39
#   c: 18 - s: 41
#   c: 33 - s: 21
# total attemps:  75
#
#   c: 0 - s: 29
#   c: 9 - s: 28
#   c: 10 - s: 52
#   c: 13 - s: 15
#   c: 16 - s: 9
#   c: 20 - s: 48
#   c: 27 - s: 6
#   c: 28 - s: 6
#   c: 30 - s: 27
#   c: 31 - s: 2
#   c: 32 - s: 6
#   c: 35 - s: 53
# total attemps:  76
#
#   c: 13 - s: 39
# total attemps:  77
#
#   c: 0 - s: 9
#   c: 18 - s: 26
#   c: 23 - s: 19
#   c: 25 - s: 27
#   c: 26 - s: 4
#   c: 27 - s: 3
#   c: 28 - s: 18
#   c: 29 - s: 11
#   c: 30 - s: 11
#   c: 31 - s: 16
# total attemps:  78
#
#   c: 6 - s: 17
#   c: 10 - s: 4
#   c: 15 - s: 59
#   c: 31 - s: 35
#   c: 34 - s: 34
# total attemps:  79
#
#   c: 2 - s: 38
#   c: 7 - s: 5
#   c: 16 - s: 25
#   c: 23 - s: 9
#   c: 25 - s: 4
# total attemps:  80
#
#   c: 16 - s: 48
#   c: 19 - s: 5
#   c: 27 - s: 14
#   c: 33 - s: 52
# total attemps:  81
#
#   c: 4 - s: 18
#   c: 17 - s: 10
#   c: 19 - s: 12
#   c: 20 - s: 15
#   c: 24 - s: 29
#   c: 25 - s: 2
#   c: 26 - s: 14
#   c: 27 - s: 8
#   c: 30 - s: 18
#   c: 32 - s: 17
# total attemps:  82
#
#   c: 2 - s: 4
#   c: 5 - s: 4
#   c: 6 - s: 28
#   c: 7 - s: 24
#   c: 18 - s: 40
#   c: 23 - s: 49
#   c: 34 - s: 5
# total attemps:  83
#
#   c: 4 - s: 17
#   c: 7 - s: 9
#   c: 15 - s: 13
#   c: 19 - s: 6
#   c: 21 - s: 5
#   c: 23 - s: 8
#   c: 24 - s: 20
#   c: 27 - s: 17
#   c: 28 - s: 22
#   c: 30 - s: 20
#   c: 32 - s: 55
# total attemps:  84
#
#   c: 14 - s: 10
#   c: 25 - s: 4
# total attemps:  85
#
#   c: 2 - s: 4
#   c: 4 - s: 21
#   c: 17 - s: 6
#   c: 18 - s: 36
#   c: 19 - s: 36
#   c: 24 - s: 12
#   c: 27 - s: 10
#   c: 31 - s: 4
#   c: 33 - s: 39
# total attemps:  86
#
#   c: 9 - s: 50
#   c: 13 - s: 4
#   c: 16 - s: 15
#   c: 18 - s: 42
#   c: 24 - s: 4
#   c: 27 - s: 26
#   c: 28 - s: 9
#   c: 29 - s: 5
#   c: 35 - s: 3
# total attemps:  87
#
#   c: 8 - s: 32
#   c: 10 - s: 5
#   c: 15 - s: 5
#   c: 17 - s: 13
#   c: 23 - s: 3
#   c: 24 - s: 3
#   c: 25 - s: 11
#   c: 27 - s: 58
#   c: 30 - s: 14
#   c: 31 - s: 35
#   c: 32 - s: 5
#   c: 33 - s: 15
#   c: 34 - s: 59
#   c: 35 - s: 5
# total attemps:  88
#
#   c: 0 - s: 26
#   c: 9 - s: 55
#   c: 10 - s: 4
#   c: 14 - s: 19
#   c: 21 - s: 4
#   c: 23 - s: 33
#   c: 24 - s: 5
#   c: 25 - s: 23
#   c: 27 - s: 7
#   c: 29 - s: 4
#   c: 31 - s: 13
#   c: 34 - s: 12
# total attemps:  89
#
#   c: 3 - s: 18
#   c: 8 - s: 5
#   c: 10 - s: 19
#   c: 13 - s: 10
#   c: 26 - s: 5
#   c: 31 - s: 20
#   c: 33 - s: 5
#   c: 35 - s: 6
# total attemps:  90
#
#   c: 0 - s: 22
#   c: 10 - s: 26
#   c: 12 - s: 25
#   c: 15 - s: 43
#   c: 18 - s: 12
#   c: 20 - s: 8
#   c: 22 - s: 7
#   c: 24 - s: 10
#   c: 25 - s: 57
#   c: 26 - s: 23
#   c: 31 - s: 6
#   c: 33 - s: 13
# total attemps:  91
#
#   c: 0 - s: 8
#   c: 4 - s: 1
#   c: 5 - s: 18
#   c: 12 - s: 59
#   c: 15 - s: 5
#   c: 18 - s: 12
#   c: 22 - s: 10
#   c: 26 - s: 5
#   c: 27 - s: 41
#   c: 30 - s: 25
#   c: 31 - s: 29
#   c: 34 - s: 8
# total attemps:  92
#
#   c: 5 - s: 33
#   c: 10 - s: 43
#   c: 13 - s: 18
#   c: 14 - s: 23
#   c: 19 - s: 8
#   c: 21 - s: 21
#   c: 22 - s: 7
#   c: 26 - s: 9
#   c: 31 - s: 46
#   c: 32 - s: 12
#   c: 34 - s: 4
# total attemps:  93
#
#   c: 7 - s: 32
#   c: 20 - s: 36
#   c: 34 - s: 13
#   c: 35 - s: 15
# total attemps:  94
#
#   c: 2 - s: 37
#   c: 9 - s: 56
#   c: 12 - s: 14
#   c: 16 - s: 3
#   c: 21 - s: 7
#   c: 24 - s: 6
#   c: 26 - s: 6
#   c: 30 - s: 4
#   c: 31 - s: 22
#   c: 33 - s: 25
#   c: 35 - s: 39
# total attemps:  95
#
#   c: 5 - s: 56
#   c: 12 - s: 3
#   c: 18 - s: 32
#   c: 24 - s: 5
#   c: 25 - s: 14
#   c: 27 - s: 34
#   c: 28 - s: 30
#   c: 31 - s: 18
#   c: 32 - s: 2
# total attemps:  96
#
#   c: 5 - s: 4
#   c: 7 - s: 18
#   c: 9 - s: 5
#   c: 17 - s: 5
#   c: 23 - s: 21
#   c: 29 - s: 15
#   c: 32 - s: 59
#   c: 34 - s: 5
# total attemps:  97
#
#   c: 4 - s: 3
#   c: 5 - s: 14
#   c: 9 - s: 30
#   c: 13 - s: 54
#   c: 17 - s: 54
#   c: 19 - s: 5
#   c: 20 - s: 17
#   c: 21 - s: 13
#   c: 23 - s: 27
#   c: 24 - s: 57
#   c: 29 - s: 8
#   c: 31 - s: 7
#   c: 33 - s: 8
# total attemps:  98
#
#   c: 5 - s: 10
#   c: 7 - s: 29
#   c: 9 - s: 2
#   c: 12 - s: 18
#   c: 18 - s: 4
#   c: 24 - s: 3
#   c: 26 - s: 4
#   c: 27 - s: 7
#   c: 30 - s: 23
# total attemps:  99
#
#   c: 4 - s: 44
#   c: 7 - s: 51
#   c: 11 - s: 35
#   c: 13 - s: 16
#   c: 14 - s: 4
#   c: 16 - s: 8
#   c: 23 - s: 20
#   c: 24 - s: 36
#   c: 25 - s: 14
#   c: 27 - s: 55
#   c: 31 - s: 3
#   c: 33 - s: 6
#   c: 34 - s: 4
#   c: 35 - s: 18
# total attemps:  100
#
#   c: 18 - s: 31
#   c: 32 - s: 18
# total attemps:  101
#
#   c: 4 - s: 35
#   c: 10 - s: 8
#   c: 15 - s: 58
#   c: 18 - s: 32
#   c: 22 - s: 39
#   c: 28 - s: 51
#   c: 31 - s: 3
# total attemps:  102
#
#   c: 2 - s: 9
#   c: 12 - s: 26
#   c: 13 - s: 25
#   c: 15 - s: 4
#   c: 17 - s: 17
#   c: 18 - s: 5
#   c: 21 - s: 12
#   c: 22 - s: 26
#   c: 26 - s: 18
#   c: 32 - s: 21
#   c: 35 - s: 16
# total attemps:  103
#
#   c: 12 - s: 13
# total attemps:  104
#
#   c: 9 - s: 47
#   c: 18 - s: 35
#   c: 20 - s: 33
#   c: 27 - s: 50
#   c: 32 - s: 5
#   c: 33 - s: 37
#   c: 34 - s: 6
# total attemps:  105
#
#   c: 8 - s: 49
#   c: 12 - s: 21
#   c: 16 - s: 31
#   c: 17 - s: 30
#   c: 24 - s: 10
#   c: 29 - s: 18
#   c: 34 - s: 11
# total attemps:  106
#
#   c: 13 - s: 44
#   c: 32 - s: 44
#   c: 33 - s: 57
#   c: 34 - s: 34
# total attemps:  107
#
#   c: 17 - s: 19
#   c: 22 - s: 19
#   c: 33 - s: 54
# total attemps:  108
#
#   c: 5 - s: 59
#   c: 7 - s: 26
#   c: 9 - s: 13
#   c: 10 - s: 10
#   c: 12 - s: 5
#   c: 17 - s: 9
#   c: 20 - s: 57
#   c: 21 - s: 3
#   c: 23 - s: 9
#   c: 27 - s: 10
#   c: 29 - s: 6
#   c: 30 - s: 11
#   c: 32 - s: 6
#   c: 33 - s: 28
# total attemps:  109
#
#   c: 5 - s: 10
#   c: 6 - s: 21
#   c: 8 - s: 19
#   c: 13 - s: 10
#   c: 24 - s: 16
#   c: 27 - s: 12
#   c: 28 - s: 9
#   c: 30 - s: 58
#   c: 32 - s: 3
#   c: 34 - s: 26
#   c: 35 - s: 11
# total attemps:  110
#
#   c: 0 - s: 3
#   c: 8 - s: 9
#   c: 14 - s: 4
#   c: 15 - s: 8
#   c: 21 - s: 9
#   c: 22 - s: 53
#   c: 24 - s: 14
#   c: 27 - s: 25
#   c: 29 - s: 6
#   c: 31 - s: 35
#   c: 32 - s: 7
#   c: 34 - s: 15
# total attemps:  111
#
#   c: 1 - s: 26
#   c: 5 - s: 28
#   c: 12 - s: 50
#   c: 13 - s: 4
#   c: 15 - s: 21
#   c: 20 - s: 12
#   c: 23 - s: 10
#   c: 25 - s: 21
#   c: 27 - s: 9
#   c: 29 - s: 9
#   c: 33 - s: 41
#   c: 34 - s: 3
#   c: 35 - s: 6
# total attemps:  112
#
#   c: 16 - s: 28
#   c: 19 - s: 24
#   c: 27 - s: 11
# total attemps:  113
#
#   c: 6 - s: 7
#   c: 7 - s: 27
#   c: 26 - s: 30
#   c: 31 - s: 13
# total attemps:  114
#
#   c: 3 - s: 23
#   c: 12 - s: 10
#   c: 15 - s: 6
#   c: 22 - s: 40
#   c: 25 - s: 18
#   c: 26 - s: 31
#   c: 27 - s: 11
#   c: 28 - s: 6
#   c: 31 - s: 3
#   c: 35 - s: 4
# total attemps:  115
#
#   c: 4 - s: 8
#   c: 6 - s: 30
#   c: 30 - s: 20
# total attemps:  116
#
#   c: 4 - s: 38
#   c: 10 - s: 32
#   c: 20 - s: 13
#   c: 21 - s: 30
#   c: 24 - s: 28
#   c: 26 - s: 46
#   c: 31 - s: 30
#   c: 32 - s: 10
# total attemps:  117
#
#   c: 7 - s: 31
#   c: 16 - s: 22
#   c: 19 - s: 46
#   c: 22 - s: 17
#   c: 23 - s: 38
#   c: 30 - s: 24
#   c: 32 - s: 19
# total attemps:  118
#
#   c: 16 - s: 11
#   c: 17 - s: 33
#   c: 26 - s: 3
#   c: 30 - s: 53
#   c: 32 - s: 12
#   c: 33 - s: 6
# total attemps:  119
#
#   c: 4 - s: 10
#   c: 11 - s: 6
#   c: 18 - s: 18
#   c: 22 - s: 12
#   c: 34 - s: 23
# total attemps:  120
#
#   c: 2 - s: 4
#   c: 10 - s: 21
#   c: 13 - s: 27
#   c: 18 - s: 4
#   c: 24 - s: 30
#   c: 27 - s: 50
#   c: 29 - s: 16
#   c: 31 - s: 28
#   c: 32 - s: 26
#   c: 34 - s: 4
#   c: 35 - s: 46
# total attemps:  121
#
#   c: 8 - s: 17
#   c: 10 - s: 7
#   c: 15 - s: 7
#   c: 16 - s: 31
#   c: 18 - s: 4
#   c: 19 - s: 14
#   c: 22 - s: 55
#   c: 23 - s: 12
#   c: 26 - s: 8
#   c: 27 - s: 6
#   c: 28 - s: 43
#   c: 29 - s: 7
#   c: 30 - s: 27
#   c: 33 - s: 22
#   c: 35 - s: 12
# total attemps:  122
#
#   c: 8 - s: 32
#   c: 9 - s: 22
#   c: 11 - s: 28
#   c: 29 - s: 11
# total attemps:  123
#
#   c: 8 - s: 57
#   c: 22 - s: 29
#   c: 26 - s: 45
#   c: 32 - s: 20
# total attemps:  124
#
#   c: 0 - s: 5
#   c: 4 - s: 4
#   c: 8 - s: 28
#   c: 11 - s: 24
#   c: 17 - s: 14
#   c: 18 - s: 25
#   c: 20 - s: 52
#   c: 22 - s: 4
#   c: 24 - s: 15
#   c: 27 - s: 59
#   c: 33 - s: 5
# total attemps:  125
#
#   c: 12 - s: 43
#   c: 15 - s: 16
#   c: 19 - s: 7
#   c: 26 - s: 45
#   c: 33 - s: 22
# total attemps:  126
#
#   c: 4 - s: 9
#   c: 15 - s: 58
#   c: 16 - s: 14
#   c: 23 - s: 12
#   c: 30 - s: 5
# total attemps:  127
#
#   c: 23 - s: 30
#   c: 32 - s: 27
#   c: 35 - s: 6
# total attemps:  128
#
#   c: 20 - s: 11
#   c: 29 - s: 42
# total attemps:  129
#
#   c: 0 - s: 10
#   c: 2 - s: 48
#   c: 7 - s: 9
#   c: 11 - s: 11
#   c: 14 - s: 38
#   c: 15 - s: 2
#   c: 18 - s: 23
#   c: 22 - s: 6
#   c: 25 - s: 7
#   c: 29 - s: 15
#   c: 35 - s: 2
# total attemps:  130
#
#   c: 0 - s: 53
#   c: 7 - s: 45
#   c: 21 - s: 11
#   c: 28 - s: 42
#   c: 35 - s: 10
# total attemps:  131
#
#   c: 1 - s: 42
#   c: 11 - s: 34
#   c: 12 - s: 3
#   c: 15 - s: 8
#   c: 27 - s: 12
#   c: 28 - s: 12
#   c: 29 - s: 15
#   c: 30 - s: 3
#   c: 32 - s: 3
#   c: 35 - s: 36
# total attemps:  132
#
#   c: 21 - s: 7
#   c: 28 - s: 49
#   c: 33 - s: 35
#   c: 34 - s: 21
# total attemps:  133
#
#   c: 0 - s: 8
#   c: 8 - s: 46
#   c: 13 - s: 4
#   c: 17 - s: 40
#   c: 23 - s: 41
#   c: 24 - s: 2
#   c: 25 - s: 12
#   c: 32 - s: 3
#   c: 34 - s: 15
#   c: 35 - s: 6
# total attemps:  134
#
#   c: 0 - s: 35
#   c: 19 - s: 12
#   c: 34 - s: 54
# total attemps:  135
#
#   c: 27 - s: 48
#   c: 29 - s: 51
# total attemps:  136
#
#   c: 15 - s: 14
#   c: 24 - s: 20
#   c: 27 - s: 32
# total attemps:  137
#
#   c: 9 - s: 50
#   c: 11 - s: 18
#   c: 18 - s: 7
#   c: 20 - s: 5
#   c: 21 - s: 31
#   c: 22 - s: 20
#   c: 28 - s: 11
#   c: 30 - s: 13
#   c: 31 - s: 4
#   c: 33 - s: 34
#   c: 34 - s: 28
#   c: 35 - s: 10
# total attemps:  138
#
#   c: 5 - s: 15
#   c: 8 - s: 5
#   c: 12 - s: 6
#   c: 15 - s: 12
#   c: 20 - s: 15
#   c: 21 - s: 44
#   c: 22 - s: 24
#   c: 23 - s: 28
#   c: 24 - s: 9
#   c: 26 - s: 18
#   c: 31 - s: 7
#   c: 34 - s: 6
# total attemps:  139
#
#   c: 2 - s: 15
#   c: 5 - s: 7
#   c: 13 - s: 5
#   c: 14 - s: 8
#   c: 18 - s: 17
#   c: 22 - s: 14
#   c: 24 - s: 43
#   c: 26 - s: 6
#   c: 30 - s: 12
# total attemps:  140
#
#   c: 3 - s: 6
#   c: 7 - s: 6
#   c: 12 - s: 8
#   c: 16 - s: 6
#   c: 23 - s: 37
#   c: 28 - s: 20
#   c: 29 - s: 29
#   c: 32 - s: 34
#   c: 33 - s: 8
#   c: 34 - s: 4
#   c: 35 - s: 29
# total attemps:  141
#
#   c: 10 - s: 8
#   c: 14 - s: 32
#   c: 23 - s: 51
#   c: 28 - s: 29
# total attemps:  142
#
#   c: 13 - s: 30
#   c: 15 - s: 18
#   c: 31 - s: 34
# total attemps:  143
#
#   c: 4 - s: 50
#   c: 8 - s: 17
#   c: 19 - s: 19
#   c: 34 - s: 46
# total attemps:  144
#
#   c: 5 - s: 6
#   c: 27 - s: 10
#   c: 33 - s: 19
# total attemps:  145
#
#   c: 20 - s: 4
#   c: 26 - s: 16
#   c: 27 - s: 41
# total attemps:  146
#
#   c: 1 - s: 6
#   c: 22 - s: 10
#   c: 24 - s: 24
#   c: 26 - s: 16
#   c: 27 - s: 33
#   c: 29 - s: 6
#   c: 32 - s: 31
# total attemps:  147
#
#   c: 3 - s: 19
#   c: 8 - s: 9
#   c: 11 - s: 21
#   c: 18 - s: 23
#   c: 23 - s: 47
#   c: 35 - s: 5
# total attemps:  148
#
#   c: 1 - s: 5
#   c: 9 - s: 29
#   c: 11 - s: 30
#   c: 18 - s: 22
#   c: 23 - s: 38
#   c: 26 - s: 21
#   c: 29 - s: 5
#   c: 32 - s: 17
#   c: 33 - s: 16
# total attemps:  149
#
#   c: 2 - s: 6
#   c: 5 - s: 15
#   c: 7 - s: 3
#   c: 8 - s: 6
#   c: 11 - s: 5
#   c: 16 - s: 8
#   c: 18 - s: 7
#   c: 22 - s: 6
#   c: 23 - s: 16
#   c: 26 - s: 27
#   c: 27 - s: 12
#   c: 32 - s: 12
#   c: 35 - s: 11
# total attemps:  150
#
#   c: 0 - s: 15
#   c: 4 - s: 16
#   c: 7 - s: 9
#   c: 16 - s: 4
#   c: 18 - s: 2
#   c: 22 - s: 11
#   c: 24 - s: 54
#   c: 29 - s: 3
#   c: 31 - s: 14
#   c: 32 - s: 25
# total attemps:  151
#
#   c: 14 - s: 23
#   c: 33 - s: 5
# total attemps:  152
#
#   c: 5 - s: 5
#   c: 6 - s: 26
#   c: 10 - s: 8
#   c: 13 - s: 13
#   c: 15 - s: 4
#   c: 22 - s: 3
#   c: 27 - s: 9
#   c: 28 - s: 24
#   c: 30 - s: 9
#   c: 33 - s: 22
#   c: 35 - s: 1
# total attemps:  153
#
#   c: 4 - s: 20
#   c: 8 - s: 29
#   c: 17 - s: 17
#   c: 32 - s: 41
# total attemps:  154
#
#   c: 11 - s: 8
#   c: 18 - s: 3
#   c: 23 - s: 3
#   c: 28 - s: 8
#   c: 29 - s: 15
#   c: 30 - s: 39
#   c: 35 - s: 20
# total attemps:  155
#
#   c: 9 - s: 5
#   c: 18 - s: 44
#   c: 23 - s: 42
#   c: 27 - s: 26
# total attemps:  156
#
#   c: 15 - s: 30
#   c: 18 - s: 37
#   c: 20 - s: 42
#   c: 21 - s: 43
#   c: 25 - s: 4
#   c: 30 - s: 18
#   c: 32 - s: 29
#   c: 34 - s: 53
# total attemps:  157
#
#   c: 0 - s: 52
#   c: 6 - s: 24
#   c: 21 - s: 5
#   c: 25 - s: 12
#   c: 31 - s: 42
# total attemps:  158
#
#   c: 1 - s: 51
#   c: 14 - s: 4
#   c: 16 - s: 14
#   c: 21 - s: 3
#   c: 22 - s: 43
#   c: 27 - s: 43
#   c: 28 - s: 13
#   c: 32 - s: 4
#   c: 33 - s: 11
#   c: 34 - s: 5
# total attemps:  159
#
#   c: 2 - s: 21
#   c: 5 - s: 37
#   c: 7 - s: 9
#   c: 8 - s: 41
#   c: 12 - s: 44
#   c: 16 - s: 25
#   c: 17 - s: 4
#   c: 20 - s: 42
#   c: 21 - s: 28
#   c: 23 - s: 29
#   c: 35 - s: 18
# total attemps:  160
#
#   c: 5 - s: 22
#   c: 16 - s: 3
#   c: 24 - s: 10
#   c: 29 - s: 7
#   c: 30 - s: 10
#   c: 31 - s: 4
#   c: 32 - s: 5
#   c: 33 - s: 49
# total attemps:  161
#
#   c: 9 - s: 11
#   c: 18 - s: 42
#   c: 24 - s: 42
#   c: 30 - s: 25
#   c: 35 - s: 16
# total attemps:  162
#
#   c: 7 - s: 7
#   c: 10 - s: 38
#   c: 13 - s: 5
#   c: 15 - s: 25
#   c: 16 - s: 5
#   c: 17 - s: 40
#   c: 20 - s: 23
#   c: 21 - s: 6
#   c: 25 - s: 19
#   c: 27 - s: 3
#   c: 29 - s: 19
#   c: 30 - s: 16
#   c: 32 - s: 17
#   c: 34 - s: 57
# total attemps:  163
#
#   c: 0 - s: 7
#   c: 3 - s: 14
#   c: 4 - s: 11
#   c: 11 - s: 37
#   c: 14 - s: 46
#   c: 18 - s: 3
#   c: 20 - s: 19
#   c: 23 - s: 8
#   c: 25 - s: 7
#   c: 28 - s: 3
#   c: 29 - s: 56
# total attemps:  164
#
#   c: 9 - s: 25
#   c: 10 - s: 42
#   c: 16 - s: 4
# total attemps:  165
#
#   c: 16 - s: 29
#   c: 21 - s: 9
#   c: 26 - s: 41
#   c: 31 - s: 59
# total attemps:  166
#
#   c: 9 - s: 15
#   c: 19 - s: 4
#   c: 26 - s: 29
#   c: 31 - s: 47
# total attemps:  167
#
#   c: 0 - s: 25
#   c: 3 - s: 19
#   c: 6 - s: 25
#   c: 10 - s: 10
#   c: 14 - s: 31
#   c: 17 - s: 17
#   c: 18 - s: 11
#   c: 22 - s: 12
#   c: 24 - s: 12
#   c: 25 - s: 21
#   c: 27 - s: 5
#   c: 28 - s: 8
#   c: 30 - s: 18
#   c: 31 - s: 4
# total attemps:  168
#
#   c: 11 - s: 44
#   c: 17 - s: 44
#   c: 20 - s: 34
#   c: 31 - s: 5
#   c: 34 - s: 30
# total attemps:  169
#
#   c: 6 - s: 19
#   c: 7 - s: 4
#   c: 9 - s: 13
#   c: 17 - s: 35
#   c: 18 - s: 5
#   c: 20 - s: 31
#   c: 27 - s: 5
#   c: 28 - s: 23
#   c: 34 - s: 13
#   c: 35 - s: 30
# total attemps:  170
#
#   c: 14 - s: 11
#   c: 25 - s: 48
#   c: 27 - s: 16
#   c: 30 - s: 39
#   c: 33 - s: 42
#   c: 35 - s: 57
# total attemps:  171
#
#   c: 6 - s: 38
#   c: 13 - s: 9
#   c: 18 - s: 12
#   c: 20 - s: 8
#   c: 22 - s: 54
#   c: 23 - s: 11
#   c: 27 - s: 58
#   c: 30 - s: 25
#   c: 32 - s: 48
#   c: 33 - s: 23
#   c: 35 - s: 17
# total attemps:  172
#
#   c: 11 - s: 54
#   c: 12 - s: 32
#   c: 16 - s: 23
#   c: 19 - s: 52
#   c: 21 - s: 38
#   c: 22 - s: 52
#   c: 23 - s: 3
#   c: 24 - s: 22
#   c: 25 - s: 19
#   c: 28 - s: 8
#   c: 29 - s: 12
#   c: 35 - s: 25
# total attemps:  173
#
#   c: 0 - s: 17
#   c: 14 - s: 13
#   c: 16 - s: 20
#   c: 25 - s: 5
# total attemps:  174
#
#   c: 0 - s: 57
#   c: 3 - s: 19
#   c: 5 - s: 57
#   c: 8 - s: 13
#   c: 13 - s: 12
#   c: 15 - s: 7
#   c: 23 - s: 34
#   c: 24 - s: 8
#   c: 25 - s: 31
#   c: 28 - s: 19
#   c: 29 - s: 23
#   c: 31 - s: 45
#   c: 32 - s: 6
# total attemps:  175
#
#   c: 9 - s: 12
#   c: 12 - s: 8
#   c: 16 - s: 14
#   c: 17 - s: 42
#   c: 18 - s: 8
#   c: 23 - s: 10
#   c: 25 - s: 11
#   c: 28 - s: 6
#   c: 29 - s: 5
#   c: 34 - s: 39
#   c: 35 - s: 14
# total attemps:  176
#
#   c: 4 - s: 8
#   c: 8 - s: 10
#   c: 16 - s: 12
#   c: 18 - s: 8
#   c: 19 - s: 18
#   c: 20 - s: 14
#   c: 24 - s: 7
#   c: 27 - s: 27
#   c: 30 - s: 17
#   c: 31 - s: 7
#   c: 34 - s: 38
# total attemps:  177
#
#   c: 11 - s: 9
#   c: 13 - s: 8
#   c: 18 - s: 23
#   c: 19 - s: 10
#   c: 23 - s: 3
#   c: 25 - s: 24
#   c: 27 - s: 8
#   c: 28 - s: 17
#   c: 31 - s: 25
# total attemps:  178
#
#   c: 4 - s: 32
#   c: 10 - s: 36
#   c: 17 - s: 33
#   c: 23 - s: 45
#   c: 34 - s: 57
# total attemps:  179
#
#   c: 0 - s: 6
#   c: 4 - s: 7
#   c: 7 - s: 11
#   c: 14 - s: 16
#   c: 23 - s: 25
#   c: 26 - s: 32
#   c: 27 - s: 1
#   c: 29 - s: 13
#   c: 35 - s: 14
# total attemps:  180
#
#   c: 5 - s: 25
#   c: 14 - s: 30
#   c: 16 - s: 18
#   c: 20 - s: 3
#   c: 21 - s: 20
#   c: 24 - s: 3
#   c: 26 - s: 35
#   c: 27 - s: 3
#   c: 28 - s: 25
#   c: 31 - s: 14
#   c: 35 - s: 12
# total attemps:  181
#
#   c: 1 - s: 11
#   c: 5 - s: 9
#   c: 6 - s: 35
#   c: 8 - s: 4
#   c: 16 - s: 5
#   c: 18 - s: 9
#   c: 19 - s: 5
#   c: 21 - s: 11
#   c: 24 - s: 24
#   c: 26 - s: 17
#   c: 28 - s: 31
#   c: 31 - s: 9
#   c: 35 - s: 4
# total attemps:  182
#
#   c: 4 - s: 12
#   c: 14 - s: 42
#   c: 15 - s: 6
#   c: 25 - s: 3
#   c: 26 - s: 12
#   c: 27 - s: 3
#   c: 29 - s: 17
#   c: 33 - s: 31
#   c: 34 - s: 44
# total attemps:  183
#
#   c: 30 - s: 19
#   c: 34 - s: 45
# total attemps:  184
#
#   c: 0 - s: 19
#   c: 3 - s: 3
#   c: 6 - s: 14
#   c: 8 - s: 16
#   c: 16 - s: 34
#   c: 33 - s: 3
#   c: 35 - s: 24
# total attemps:  185
#
#   c: 8 - s: 32
#   c: 12 - s: 6
#   c: 28 - s: 30
#   c: 33 - s: 36
# total attemps:  186
#
#   c: 0 - s: 51
#   c: 2 - s: 22
#   c: 5 - s: 59
#   c: 7 - s: 55
#   c: 8 - s: 11
#   c: 11 - s: 7
#   c: 13 - s: 10
#   c: 23 - s: 18
#   c: 24 - s: 18
#   c: 27 - s: 8
#   c: 31 - s: 30
#   c: 34 - s: 47
# total attemps:  187
#
#   c: 2 - s: 47
#   c: 10 - s: 44
#   c: 31 - s: 44
#   c: 32 - s: 58
# total attemps:  188
#
#   c: 2 - s: 18
#   c: 7 - s: 8
#   c: 10 - s: 3
#   c: 12 - s: 50
#   c: 15 - s: 28
#   c: 22 - s: 12
#   c: 23 - s: 10
#   c: 24 - s: 18
#   c: 28 - s: 2
#   c: 35 - s: 18
# total attemps:  189
#
#   c: 4 - s: 19
#   c: 8 - s: 40
#   c: 17 - s: 49
#   c: 26 - s: 5
#   c: 27 - s: 17
#   c: 34 - s: 18
# total attemps:  190
#
#   c: 15 - s: 5
#   c: 28 - s: 19
# total attemps:  191
#
#   c: 13 - s: 10
#   c: 20 - s: 7
#   c: 22 - s: 30
#   c: 34 - s: 58
# total attemps:  192
#
#   c: 8 - s: 25
#   c: 22 - s: 24
#   c: 33 - s: 49
#   c: 35 - s: 9
# total attemps:  193
#
#   c: 10 - s: 10
#   c: 21 - s: 11
#   c: 23 - s: 19
#   c: 26 - s: 19
#   c: 35 - s: 26
# total attemps:  194
#
#   c: 6 - s: 20
#   c: 9 - s: 22
#   c: 10 - s: 40
#   c: 15 - s: 4
#   c: 19 - s: 9
#   c: 20 - s: 20
#   c: 27 - s: 4
#   c: 30 - s: 24
#   c: 34 - s: 28
#   c: 35 - s: 14
# total attemps:  195
#
#   c: 2 - s: 43
#   c: 11 - s: 38
#   c: 19 - s: 59
# total attemps:  196
#
#   c: 0 - s: 4
#   c: 10 - s: 4
#   c: 11 - s: 4
#   c: 13 - s: 7
#   c: 14 - s: 41
#   c: 19 - s: 50
#   c: 20 - s: 3
#   c: 21 - s: 7
#   c: 24 - s: 8
#   c: 26 - s: 27
#   c: 28 - s: 22
#   c: 30 - s: 53
#   c: 32 - s: 45
#   c: 33 - s: 13
# total attemps:  197
#
#   c: 13 - s: 38
#   c: 16 - s: 32
# total attemps:  198
#
#   c: 12 - s: 5
#   c: 16 - s: 9
#   c: 18 - s: 32
#   c: 21 - s: 11
#   c: 24 - s: 9
#   c: 25 - s: 15
#   c: 28 - s: 39
#   c: 31 - s: 38
# total attemps:  199
#
#   c: 8 - s: 48
#   c: 16 - s: 25
#   c: 18 - s: 54
#   c: 34 - s: 37
# total attemps:  200
#
#   c: 3 - s: 6
#   c: 7 - s: 18
#   c: 15 - s: 4
#   c: 31 - s: 58
#   c: 32 - s: 8
# total attemps:  201
#
#   c: 0 - s: 23
#   c: 15 - s: 7
#   c: 17 - s: 28
#   c: 24 - s: 46
#   c: 29 - s: 53
# total attemps:  202
#
#   c: 0 - s: 4
#   c: 7 - s: 21
#   c: 10 - s: 24
#   c: 13 - s: 16
#   c: 14 - s: 3
#   c: 17 - s: 13
#   c: 19 - s: 7
#   c: 20 - s: 54
#   c: 23 - s: 23
#   c: 24 - s: 14
#   c: 25 - s: 23
#   c: 32 - s: 27
# total attemps:  203
#
#   c: 0 - s: 28
#   c: 10 - s: 11
#   c: 13 - s: 3
#   c: 21 - s: 20
#   c: 25 - s: 47
#   c: 27 - s: 7
#   c: 28 - s: 12
#   c: 31 - s: 18
#   c: 35 - s: 16
# total attemps:  204
#
#   c: 6 - s: 11
#   c: 13 - s: 8
#   c: 15 - s: 4
#   c: 20 - s: 4
#   c: 21 - s: 28
#   c: 29 - s: 36
#   c: 30 - s: 39
#   c: 33 - s: 55
#   c: 34 - s: 19
# total attemps:  205
#
#   c: 2 - s: 27
#   c: 8 - s: 38
#   c: 16 - s: 53
#   c: 30 - s: 4
# total attemps:  206
#
#   c: 2 - s: 22
#   c: 4 - s: 9
#   c: 5 - s: 5
#   c: 9 - s: 23
#   c: 10 - s: 57
#   c: 15 - s: 2
#   c: 17 - s: 18
#   c: 19 - s: 30
#   c: 20 - s: 16
#   c: 21 - s: 10
#   c: 28 - s: 13
#   c: 29 - s: 13
#   c: 34 - s: 31
# total attemps:  207
#
#   c: 2 - s: 40
#   c: 3 - s: 14
#   c: 6 - s: 35
#   c: 10 - s: 6
#   c: 16 - s: 4
#   c: 22 - s: 25
#   c: 25 - s: 7
#   c: 28 - s: 7
#   c: 32 - s: 3
#   c: 33 - s: 14
#   c: 35 - s: 27
# total attemps:  208
#
#   c: 11 - s: 21
#   c: 18 - s: 39
#   c: 19 - s: 37
#   c: 25 - s: 27
#   c: 31 - s: 24
# total attemps:  209
#
#   c: 0 - s: 9
#   c: 8 - s: 9
#   c: 9 - s: 4
#   c: 10 - s: 8
#   c: 20 - s: 13
#   c: 24 - s: 43
#   c: 25 - s: 10
#   c: 26 - s: 25
#   c: 27 - s: 6
#   c: 30 - s: 40
#   c: 32 - s: 4
# total attemps:  210
#
#   c: 8 - s: 50
#   c: 10 - s: 53
#   c: 13 - s: 45
#   c: 19 - s: 17
#   c: 26 - s: 23
#   c: 27 - s: 43
# total attemps:  211
#
#   c: 14 - s: 13
#   c: 24 - s: 29
#   c: 28 - s: 40
#   c: 29 - s: 4
#   c: 35 - s: 23
# total attemps:  212
#
#   c: 4 - s: 34
#   c: 11 - s: 25
#   c: 13 - s: 51
#   c: 14 - s: 8
#   c: 20 - s: 8
#   c: 22 - s: 36
#   c: 23 - s: 13
#   c: 26 - s: 24
#   c: 32 - s: 8
# total attemps:  213
#
#   c: 15 - s: 33
#   c: 25 - s: 35
#   c: 34 - s: 53
# total attemps:  214
#
#   c: 16 - s: 5
#   c: 21 - s: 6
#   c: 31 - s: 18
# total attemps:  215
#
#   c: 5 - s: 44
#   c: 8 - s: 51
#   c: 20 - s: 57
#   c: 31 - s: 54
#   c: 32 - s: 53
# total attemps:  216
#
#   c: 8 - s: 39
#   c: 18 - s: 34
#   c: 23 - s: 37
#   c: 27 - s: 10
#   c: 32 - s: 41
# total attemps:  217
#
#   c: 12 - s: 29
#   c: 16 - s: 21
#   c: 17 - s: 3
#   c: 21 - s: 9
#   c: 23 - s: 17
#   c: 27 - s: 53
#   c: 28 - s: 51
#   c: 29 - s: 44
#   c: 33 - s: 7
# total attemps:  218
#
#   c: 2 - s: 10
#   c: 11 - s: 4
#   c: 12 - s: 6
#   c: 16 - s: 30
#   c: 24 - s: 3
#   c: 29 - s: 12
#   c: 30 - s: 5
#   c: 32 - s: 11
#   c: 34 - s: 9
#   c: 35 - s: 3
# total attemps:  219
#
#   c: 18 - s: 59
#   c: 24 - s: 18
#   c: 26 - s: 18
#   c: 33 - s: 14
#   c: 35 - s: 53
# total attemps:  220
#
#   c: 15 - s: 6
#   c: 18 - s: 53
# total attemps:  221
#
#   c: 5 - s: 3
#   c: 10 - s: 6
#   c: 15 - s: 31
#   c: 18 - s: 6
#   c: 27 - s: 52
#   c: 29 - s: 7
#   c: 33 - s: 4
#   c: 35 - s: 28
# total attemps:  222
#
#   c: 11 - s: 7
#   c: 29 - s: 3
# total attemps:  223
#
#   c: 3 - s: 5
#   c: 16 - s: 20
#   c: 19 - s: 24
#   c: 21 - s: 3
#   c: 23 - s: 26
# total attemps:  224
#
#   c: 4 - s: 15
#   c: 11 - s: 13
#   c: 17 - s: 6
#   c: 18 - s: 2
#   c: 22 - s: 45
#   c: 23 - s: 29
#   c: 26 - s: 21
#   c: 28 - s: 15
#   c: 31 - s: 3
#   c: 32 - s: 4
#   c: 33 - s: 16
#   c: 34 - s: 28
# total attemps:  225
#
#   c: 14 - s: 24
#   c: 19 - s: 40
# total attemps:  226
#
#   c: 5 - s: 37
#   c: 26 - s: 12
#   c: 30 - s: 47
#   c: 31 - s: 3
# total attemps:  227
#
#   c: 9 - s: 21
#   c: 12 - s: 17
#   c: 14 - s: 7
#   c: 21 - s: 39
#   c: 22 - s: 40
#   c: 23 - s: 3
#   c: 30 - s: 10
#   c: 31 - s: 45
#   c: 32 - s: 24
# total attemps:  228
#
#   c: 4 - s: 4
#   c: 12 - s: 7
#   c: 14 - s: 11
#   c: 16 - s: 47
#   c: 26 - s: 16
#   c: 27 - s: 9
#   c: 28 - s: 11
#   c: 31 - s: 10
#   c: 33 - s: 16
#   c: 34 - s: 28
#   c: 35 - s: 7
# total attemps:  229
#
#   c: 9 - s: 25
#   c: 10 - s: 7
#   c: 16 - s: 4
#   c: 19 - s: 30
#   c: 20 - s: 11
#   c: 24 - s: 50
#   c: 27 - s: 18
#   c: 28 - s: 34
#   c: 31 - s: 9
#   c: 33 - s: 22
#   c: 35 - s: 30
# total attemps:  230
#
#   c: 10 - s: 36
#   c: 22 - s: 16
#   c: 23 - s: 17
#   c: 25 - s: 23
#   c: 28 - s: 14
#   c: 32 - s: 29
# total attemps:  231
#
#   c: 3 - s: 12
#   c: 7 - s: 25
#   c: 10 - s: 12
#   c: 11 - s: 39
#   c: 15 - s: 31
#   c: 16 - s: 11
#   c: 17 - s: 16
#   c: 20 - s: 27
#   c: 25 - s: 10
#   c: 27 - s: 56
#   c: 34 - s: 12
# total attemps:  232
#
#   c: 0 - s: 15
#   c: 4 - s: 29
#   c: 5 - s: 45
#   c: 12 - s: 6
#   c: 19 - s: 39
#   c: 20 - s: 25
#   c: 27 - s: 5
#   c: 29 - s: 15
#   c: 33 - s: 5
# total attemps:  233
#
#   c: 29 - s: 20
#   c: 35 - s: 11
# total attemps:  234
#
#   c: 6 - s: 5
#   c: 12 - s: 5
#   c: 13 - s: 4
#   c: 15 - s: 2
#   c: 21 - s: 8
# total attemps:  235
#
#   c: 6 - s: 54
#   c: 8 - s: 18
#   c: 9 - s: 31
#   c: 15 - s: 9
#   c: 18 - s: 28
#   c: 30 - s: 49
#   c: 34 - s: 40
# total attemps:  236
#
#   c: 8 - s: 26
#   c: 11 - s: 16
#   c: 13 - s: 8
#   c: 15 - s: 28
#   c: 16 - s: 27
#   c: 18 - s: 17
#   c: 20 - s: 8
#   c: 24 - s: 11
#   c: 25 - s: 8
#   c: 33 - s: 27
#   c: 35 - s: 45
# total attemps:  237
#
#   c: 20 - s: 55
#   c: 22 - s: 8
#   c: 27 - s: 27
#   c: 31 - s: 38
# total attemps:  238
#
#   c: 12 - s: 19
#   c: 13 - s: 20
#   c: 24 - s: 11
#   c: 34 - s: 56
# total attemps:  239
#
#   c: 1 - s: 4
#   c: 3 - s: 21
#   c: 4 - s: 24
#   c: 8 - s: 14
#   c: 11 - s: 22
#   c: 18 - s: 9
#   c: 21 - s: 30
#   c: 25 - s: 3
#   c: 28 - s: 8
#   c: 32 - s: 6
#   c: 33 - s: 29
#   c: 34 - s: 21
# total attemps:  240
#
#   c: 10 - s: 6
#   c: 15 - s: 36
#   c: 19 - s: 5
#   c: 20 - s: 17
#   c: 21 - s: 9
#   c: 24 - s: 28
#   c: 26 - s: 38
#   c: 29 - s: 54
#   c: 30 - s: 24
#   c: 33 - s: 16
# total attemps:  241
#
#   c: 3 - s: 14
#   c: 4 - s: 8
#   c: 6 - s: 12
#   c: 10 - s: 46
#   c: 18 - s: 21
#   c: 29 - s: 48
#   c: 32 - s: 14
#   c: 34 - s: 12
# total attemps:  242
#
#   c: 13 - s: 2
#   c: 14 - s: 8
#   c: 15 - s: 5
#   c: 23 - s: 9
#   c: 25 - s: 6
#   c: 28 - s: 39
#   c: 30 - s: 6
#   c: 31 - s: 15
#   c: 32 - s: 10
#   c: 33 - s: 20
#   c: 34 - s: 7
# total attemps:  243
#
#   c: 4 - s: 5
#   c: 6 - s: 40
#   c: 7 - s: 7
#   c: 12 - s: 3
#   c: 13 - s: 8
#   c: 14 - s: 5
#   c: 15 - s: 13
#   c: 20 - s: 49
#   c: 21 - s: 14
#   c: 24 - s: 9
#   c: 25 - s: 11
#   c: 26 - s: 32
#   c: 28 - s: 5
#   c: 31 - s: 3
#   c: 35 - s: 12
# total attemps:  244
#
#   c: 7 - s: 26
#   c: 12 - s: 10
#   c: 15 - s: 54
#   c: 18 - s: 57
#   c: 21 - s: 13
#   c: 22 - s: 51
#   c: 25 - s: 36
#   c: 32 - s: 17
#   c: 33 - s: 7
# total attemps:  245
#
#   c: 2 - s: 33
#   c: 8 - s: 59
#   c: 10 - s: 4
#   c: 13 - s: 42
#   c: 15 - s: 34
#   c: 16 - s: 14
#   c: 19 - s: 46
#   c: 34 - s: 24
# total attemps:  246
#
#   c: 5 - s: 41
#   c: 16 - s: 10
#   c: 18 - s: 20
#   c: 22 - s: 13
#   c: 29 - s: 3
#   c: 33 - s: 19
# total attemps:  247
#
#   c: 8 - s: 20
#   c: 35 - s: 5
# total attemps:  248
#
#   c: 13 - s: 20
#   c: 16 - s: 3
#   c: 20 - s: 55
#   c: 24 - s: 7
#   c: 26 - s: 14
#   c: 27 - s: 45
#   c: 34 - s: 15
# total attemps:  249
#
#   c: 26 - s: 31
#   c: 28 - s: 4
# total attemps:  250
#
#   c: 12 - s: 57
#   c: 15 - s: 8
#   c: 21 - s: 14
#   c: 25 - s: 18
#   c: 29 - s: 35
#   c: 30 - s: 19
#   c: 31 - s: 25
#   c: 32 - s: 10
#   c: 33 - s: 6
#   c: 35 - s: 44
# total attemps:  251
#
#   c: 2 - s: 7
#   c: 5 - s: 3
#   c: 6 - s: 10
#   c: 10 - s: 3
#   c: 16 - s: 39
#   c: 20 - s: 16
#   c: 25 - s: 36
#   c: 28 - s: 8
#   c: 30 - s: 28
#   c: 31 - s: 15
#   c: 32 - s: 24
#   c: 33 - s: 9
# total attemps:  252
#
#   c: 7 - s: 10
#   c: 22 - s: 4
#   c: 23 - s: 4
#   c: 26 - s: 38
# total attemps:  253
#
#   c: 14 - s: 16
#   c: 19 - s: 9
#   c: 22 - s: 37
#   c: 29 - s: 45
#   c: 31 - s: 46
# total attemps:  254
#
#   c: 3 - s: 50
#   c: 18 - s: 13
#   c: 21 - s: 46
#   c: 22 - s: 53
#   c: 32 - s: 44
# total attemps:  255
#
#   c: 1 - s: 28
#   c: 4 - s: 9
#   c: 5 - s: 21
#   c: 9 - s: 51
#   c: 10 - s: 18
#   c: 12 - s: 10
#   c: 13 - s: 6
#   c: 22 - s: 35
#   c: 25 - s: 12
#   c: 28 - s: 5
#   c: 29 - s: 18
#   c: 34 - s: 3
# total attemps:  256
#
#   c: 2 - s: 7
#   c: 3 - s: 15
#   c: 6 - s: 11
#   c: 17 - s: 9
#   c: 18 - s: 52
#   c: 19 - s: 15
#   c: 21 - s: 6
#   c: 25 - s: 13
#   c: 32 - s: 39
#   c: 35 - s: 10
# total attemps:  257
#
#   c: 2 - s: 20
#   c: 21 - s: 48
#   c: 30 - s: 19
#   c: 33 - s: 46
#   c: 34 - s: 24
# total attemps:  258
#
#   c: 14 - s: 6
#   c: 17 - s: 19
#   c: 19 - s: 4
#   c: 30 - s: 4
# total attemps:  259
#
#   c: 0 - s: 57
#   c: 7 - s: 13
#   c: 13 - s: 16
#   c: 14 - s: 11
#   c: 17 - s: 17
#   c: 18 - s: 9
#   c: 19 - s: 34
#   c: 27 - s: 4
#   c: 28 - s: 15
#   c: 30 - s: 2
#   c: 33 - s: 17
#   c: 35 - s: 9
# total attemps:  260
#
#   c: 0 - s: 52
#   c: 1 - s: 56
#   c: 5 - s: 6
#   c: 7 - s: 20
#   c: 13 - s: 53
#   c: 20 - s: 14
#   c: 22 - s: 43
#   c: 23 - s: 5
#   c: 25 - s: 38
#   c: 27 - s: 31
#   c: 31 - s: 35
#   c: 33 - s: 23
#   c: 34 - s: 5
# total attemps:  261
#
#   c: 0 - s: 48
#   c: 8 - s: 22
#   c: 9 - s: 42
#   c: 11 - s: 21
#   c: 14 - s: 32
#   c: 15 - s: 4
#   c: 21 - s: 38
#   c: 24 - s: 35
#   c: 25 - s: 15
#   c: 26 - s: 23
#   c: 27 - s: 8
#   c: 30 - s: 8
#   c: 32 - s: 9
#   c: 34 - s: 20
#   c: 35 - s: 2
# total attemps:  262
#
#   c: 7 - s: 3
#   c: 23 - s: 23
#   c: 26 - s: 7
#   c: 33 - s: 3
#   c: 35 - s: 6
# total attemps:  263
#
#   c: 1 - s: 44
#   c: 17 - s: 23
# total attemps:  264
#
#   c: 9 - s: 14
#   c: 12 - s: 19
#   c: 20 - s: 8
# total attemps:  265
#
#   c: 12 - s: 4
#   c: 13 - s: 3
#   c: 16 - s: 11
#   c: 21 - s: 5
#   c: 23 - s: 14
#   c: 24 - s: 41
#   c: 30 - s: 9
#   c: 32 - s: 8
#   c: 33 - s: 24
# total attemps:  266
#
#   c: 7 - s: 22
#   c: 14 - s: 3
#   c: 20 - s: 21
#   c: 21 - s: 5
#   c: 23 - s: 32
#   c: 30 - s: 47
#   c: 31 - s: 32
#   c: 32 - s: 14
# total attemps:  267
#
#   c: 3 - s: 8
#   c: 8 - s: 18
#   c: 19 - s: 18
#   c: 25 - s: 27
#   c: 33 - s: 3
#   c: 35 - s: 5
# total attemps:  268
#
#   c: 6 - s: 56
#   c: 11 - s: 1
#   c: 12 - s: 10
# total attemps:  269
#
#   c: 1 - s: 23
#   c: 8 - s: 40
#   c: 11 - s: 25
#   c: 16 - s: 34
#   c: 33 - s: 13
# total attemps:  270
#
#   c: 2 - s: 5
#   c: 6 - s: 4
#   c: 13 - s: 14
#   c: 15 - s: 40
#   c: 17 - s: 7
#   c: 18 - s: 11
#   c: 22 - s: 3
#   c: 23 - s: 18
#   c: 28 - s: 57
#   c: 29 - s: 6
#   c: 35 - s: 10
# total attemps:  271
#
#   c: 3 - s: 6
#   c: 8 - s: 17
#   c: 19 - s: 8
#   c: 22 - s: 3
#   c: 23 - s: 5
#   c: 34 - s: 6
# total attemps:  272
#
#   c: 0 - s: 56
#   c: 13 - s: 15
#   c: 14 - s: 12
#   c: 18 - s: 18
#   c: 19 - s: 8
#   c: 20 - s: 9
#   c: 23 - s: 6
#   c: 29 - s: 47
#   c: 32 - s: 9
#   c: 35 - s: 21
# total attemps:  273
#
#   c: 7 - s: 42
#   c: 8 - s: 54
#   c: 9 - s: 9
#   c: 14 - s: 18
#   c: 15 - s: 59
#   c: 18 - s: 42
#   c: 19 - s: 11
#   c: 20 - s: 31
#   c: 23 - s: 36
#   c: 26 - s: 2
#   c: 27 - s: 16
#   c: 30 - s: 26
#   c: 33 - s: 1
# total attemps:  274
#
#   c: 0 - s: 49
#   c: 11 - s: 32
#   c: 26 - s: 19
#   c: 34 - s: 10
# total attemps:  275
#
#   c: 8 - s: 19
#   c: 23 - s: 8
# total attemps:  276
#
#   c: 9 - s: 15
#   c: 10 - s: 5
# total attemps:  277
#
#   c: 0 - s: 14
#   c: 7 - s: 3
#   c: 8 - s: 14
#   c: 17 - s: 31
#   c: 23 - s: 13
#   c: 26 - s: 41
#   c: 27 - s: 16
#   c: 31 - s: 4
#   c: 32 - s: 1
#   c: 33 - s: 6
#   c: 34 - s: 7
# total attemps:  278
#
#   c: 5 - s: 5
#   c: 7 - s: 13
#   c: 9 - s: 14
#   c: 10 - s: 6
#   c: 20 - s: 40
#   c: 23 - s: 9
#   c: 24 - s: 51
#   c: 27 - s: 5
#   c: 31 - s: 39
#   c: 33 - s: 10
# total attemps:  279
#
#   c: 5 - s: 46
#   c: 8 - s: 7
#   c: 22 - s: 35
#   c: 25 - s: 25
#   c: 27 - s: 2
#   c: 28 - s: 11
#   c: 31 - s: 14
#   c: 32 - s: 47
#   c: 33 - s: 56
# total attemps:  280
#
#   c: 17 - s: 6
#   c: 19 - s: 37
#   c: 24 - s: 47
#   c: 29 - s: 36
# total attemps:  281
#
#   c: 21 - s: 25
#   c: 30 - s: 27
# total attemps:  282
#
#   c: 2 - s: 9
#   c: 8 - s: 3
#   c: 10 - s: 16
#   c: 14 - s: 18
#   c: 15 - s: 7
#   c: 21 - s: 4
# total attemps:  283
#
#   c: 15 - s: 4
# total attemps:  284
#
#   c: 4 - s: 45
#   c: 13 - s: 54
#   c: 28 - s: 31
#   c: 32 - s: 26
# total attemps:  285
#
#   c: 5 - s: 9
#   c: 6 - s: 4
#   c: 7 - s: 22
#   c: 12 - s: 53
#   c: 14 - s: 5
#   c: 21 - s: 7
#   c: 23 - s: 8
#   c: 25 - s: 6
#   c: 28 - s: 18
#   c: 31 - s: 6
#   c: 34 - s: 16
#   c: 35 - s: 8
# total attemps:  286
#
#   c: 7 - s: 15
#   c: 8 - s: 10
#   c: 14 - s: 15
#   c: 15 - s: 46
#   c: 17 - s: 34
#   c: 23 - s: 26
#   c: 26 - s: 11
#   c: 27 - s: 3
#   c: 29 - s: 7
#   c: 30 - s: 17
#   c: 35 - s: 58
# total attemps:  287
#
#   c: 1 - s: 51
#   c: 25 - s: 8
# total attemps:  288
#
#   c: 3 - s: 6
#   c: 13 - s: 26
#   c: 18 - s: 3
#   c: 21 - s: 31
#   c: 23 - s: 32
# total attemps:  289
#
#   c: 11 - s: 12
#   c: 12 - s: 3
#   c: 15 - s: 5
#   c: 16 - s: 27
#   c: 17 - s: 27
#   c: 21 - s: 31
#   c: 25 - s: 8
#   c: 27 - s: 11
#   c: 32 - s: 28
#   c: 35 - s: 5
# total attemps:  290
#
#   c: 4 - s: 11
#   c: 5 - s: 18
#   c: 9 - s: 13
#   c: 11 - s: 4
#   c: 26 - s: 21
#   c: 32 - s: 27
# total attemps:  291
#
#   c: 11 - s: 4
#   c: 25 - s: 7
#   c: 30 - s: 24
#   c: 32 - s: 12
# total attemps:  292
#
#   c: 4 - s: 12
#   c: 11 - s: 10
#   c: 14 - s: 33
#   c: 15 - s: 4
#   c: 20 - s: 2
#   c: 22 - s: 4
#   c: 27 - s: 9
#   c: 29 - s: 41
#   c: 32 - s: 20
#   c: 35 - s: 8
# total attemps:  293
#
#   c: 0 - s: 46
#   c: 3 - s: 23
#   c: 8 - s: 16
#   c: 9 - s: 9
#   c: 10 - s: 5
#   c: 12 - s: 4
#   c: 16 - s: 19
#   c: 17 - s: 3
#   c: 21 - s: 8
#   c: 26 - s: 52
#   c: 32 - s: 10
#   c: 33 - s: 10
#   c: 34 - s: 18
#   c: 35 - s: 23
# total attemps:  294
#
#   c: 10 - s: 27
#   c: 13 - s: 31
#   c: 22 - s: 12
#   c: 30 - s: 4
#   c: 32 - s: 4
#   c: 33 - s: 14
#   c: 34 - s: 20
# total attemps:  295
#
#   c: 4 - s: 25
#   c: 29 - s: 52
# total attemps:  296
#
#   c: 20 - s: 19
#   c: 23 - s: 23
#   c: 29 - s: 3
# total attemps:  297
#
#   c: 0 - s: 39
#   c: 20 - s: 26
#   c: 23 - s: 28
#   c: 26 - s: 43
#   c: 31 - s: 18
#   c: 34 - s: 18
# total attemps:  298
#
#   c: 5 - s: 31
#   c: 6 - s: 13
#   c: 14 - s: 3
#   c: 19 - s: 10
#   c: 35 - s: 18
# total attemps:  299
#
#   c: 0 - s: 43
#   c: 7 - s: 13
#   c: 17 - s: 31
#   c: 25 - s: 27
# total attemps:  300
#
#   c: 17 - s: 8
#   c: 23 - s: 9
#   c: 27 - s: 37
#   c: 28 - s: 17
#   c: 30 - s: 38
#   c: 32 - s: 27
#   c: 33 - s: 13
#   c: 34 - s: 39
#   c: 35 - s: 53
# total attemps:  301
#
#   c: 11 - s: 52
#   c: 12 - s: 11
#   c: 14 - s: 48
#   c: 15 - s: 4
#   c: 23 - s: 11
#   c: 25 - s: 15
#   c: 30 - s: 31
#   c: 34 - s: 9
#   c: 35 - s: 12
# total attemps:  302
#
#   c: 18 - s: 21
#   c: 27 - s: 21
#   c: 34 - s: 13
#   c: 35 - s: 9
# total attemps:  303
#
#   c: 14 - s: 35
#   c: 18 - s: 58
#   c: 20 - s: 51
#   c: 26 - s: 43
#   c: 35 - s: 20
# total attemps:  304
#
#   c: 10 - s: 59
#   c: 12 - s: 6
#   c: 13 - s: 6
#   c: 21 - s: 4
#   c: 23 - s: 27
#   c: 28 - s: 6
#   c: 32 - s: 16
#   c: 34 - s: 3
# total attemps:  305
#
#   c: 8 - s: 34
#   c: 9 - s: 30
#   c: 10 - s: 7
#   c: 33 - s: 15
# total attemps:  306
#
#   c: 3 - s: 18
#   c: 4 - s: 9
#   c: 5 - s: 17
#   c: 6 - s: 4
#   c: 14 - s: 7
#   c: 24 - s: 6
#   c: 25 - s: 27
#   c: 35 - s: 52
# total attemps:  307
#
#   c: 1 - s: 13
#   c: 6 - s: 13
#   c: 9 - s: 10
#   c: 11 - s: 6
#   c: 21 - s: 17
#   c: 22 - s: 22
#   c: 30 - s: 46
#   c: 31 - s: 5
#   c: 32 - s: 46
#   c: 35 - s: 21
# total attemps:  308
#
#   c: 29 - s: 8
#   c: 30 - s: 29
# total attemps:  309
#
#   c: 7 - s: 56
#   c: 9 - s: 6
#   c: 10 - s: 8
#   c: 12 - s: 21
#   c: 22 - s: 3
#   c: 24 - s: 14
#   c: 31 - s: 4
# total attemps:  310
#
#   c: 2 - s: 19
#   c: 3 - s: 22
#   c: 10 - s: 50
#   c: 11 - s: 8
#   c: 20 - s: 44
#   c: 25 - s: 9
#   c: 28 - s: 49
#   c: 29 - s: 27
#   c: 31 - s: 2
#   c: 32 - s: 6
#   c: 33 - s: 34
# total attemps:  311
#
#   c: 27 - s: 52
# total attemps:  312
#
#   c: 0 - s: 45
#   c: 15 - s: 43
#   c: 16 - s: 3
#   c: 18 - s: 9
#   c: 20 - s: 5
#   c: 28 - s: 30
#   c: 30 - s: 21
#   c: 32 - s: 22
#   c: 35 - s: 21
# total attemps:  313
#
#   c: 0 - s: 7
#   c: 5 - s: 37
#   c: 15 - s: 6
#   c: 16 - s: 3
#   c: 17 - s: 12
#   c: 18 - s: 28
#   c: 20 - s: 49
#   c: 23 - s: 11
#   c: 25 - s: 56
#   c: 26 - s: 21
#   c: 28 - s: 16
#   c: 30 - s: 47
#   c: 32 - s: 20
# total attemps:  314
#
#   c: 3 - s: 26
#   c: 12 - s: 47
#   c: 15 - s: 31
#   c: 24 - s: 3
#   c: 27 - s: 55
# total attemps:  315
#
#   c: 6 - s: 7
#   c: 14 - s: 30
# total attemps:  316
#
#   c: 0 - s: 25
#   c: 10 - s: 2
#   c: 13 - s: 9
#   c: 14 - s: 33
#   c: 18 - s: 8
#   c: 22 - s: 25
#   c: 28 - s: 30
#   c: 29 - s: 10
#   c: 30 - s: 15
#   c: 33 - s: 5
# total attemps:  317
#
#   c: 3 - s: 55
#   c: 9 - s: 3
#   c: 11 - s: 30
#   c: 12 - s: 21
#   c: 18 - s: 28
#   c: 21 - s: 13
#   c: 22 - s: 25
#   c: 26 - s: 19
#   c: 29 - s: 7
#   c: 30 - s: 49
#   c: 31 - s: 7
#   c: 32 - s: 12
#   c: 33 - s: 10
#   c: 35 - s: 51
# total attemps:  318
#
#   c: 9 - s: 18
#   c: 10 - s: 6
#   c: 15 - s: 10
#   c: 16 - s: 24
#   c: 19 - s: 3
#   c: 20 - s: 11
#   c: 21 - s: 50
#   c: 27 - s: 6
#   c: 28 - s: 40
#   c: 30 - s: 8
#   c: 31 - s: 17
#   c: 32 - s: 5
# total attemps:  319
#
#   c: 5 - s: 38
#   c: 20 - s: 11
# total attemps:  320
#
#   c: 13 - s: 28
#   c: 14 - s: 4
#   c: 17 - s: 5
#   c: 28 - s: 33
# total attemps:  321
#
#   c: 15 - s: 13
#   c: 16 - s: 56
#   c: 21 - s: 4
# total attemps:  322
#
#   c: 3 - s: 16
#   c: 8 - s: 7
#   c: 9 - s: 12
#   c: 21 - s: 51
#   c: 23 - s: 25
#   c: 26 - s: 17
#   c: 29 - s: 8
#   c: 31 - s: 12
#   c: 32 - s: 54
#   c: 33 - s: 9
#   c: 35 - s: 24
# total attemps:  323
#
#   c: 11 - s: 33
#   c: 19 - s: 12
#   c: 28 - s: 7
# total attemps:  324
#
#   c: 5 - s: 13
#   c: 10 - s: 21
#   c: 15 - s: 4
#   c: 20 - s: 13
#   c: 22 - s: 5
#   c: 26 - s: 6
#   c: 29 - s: 4
#   c: 30 - s: 19
#   c: 32 - s: 6
#   c: 34 - s: 12
# total attemps:  325
#
#   c: 8 - s: 19
#   c: 24 - s: 44
#   c: 30 - s: 41
#   c: 34 - s: 55
# total attemps:  326
#
#   c: 12 - s: 26
#   c: 17 - s: 19
#   c: 30 - s: 36
#   c: 31 - s: 52
#   c: 32 - s: 22
# total attemps:  327
#
#   c: 8 - s: 21
#   c: 17 - s: 34
#   c: 19 - s: 7
#   c: 22 - s: 15
#   c: 34 - s: 8
# total attemps:  328
#
#   c: 0 - s: 1
#   c: 10 - s: 38
#   c: 23 - s: 3
#   c: 24 - s: 26
#   c: 25 - s: 44
#   c: 26 - s: 37
#   c: 27 - s: 17
# total attemps:  329
#
#   c: 0 - s: 27
#   c: 1 - s: 43
#   c: 26 - s: 34
#   c: 27 - s: 42
#   c: 33 - s: 34
# total attemps:  330
#
#   c: 18 - s: 52
#   c: 27 - s: 40
# total attemps:  331
#
#   c: 0 - s: 31
#   c: 2 - s: 21
#   c: 4 - s: 45
#   c: 11 - s: 12
#   c: 22 - s: 5
#   c: 25 - s: 24
#   c: 26 - s: 12
#   c: 27 - s: 3
#   c: 30 - s: 15
#   c: 32 - s: 20
# total attemps:  332
#
#   c: 5 - s: 1
#   c: 8 - s: 3
#   c: 9 - s: 22
#   c: 12 - s: 6
#   c: 13 - s: 7
#   c: 14 - s: 39
#   c: 15 - s: 4
#   c: 16 - s: 45
#   c: 20 - s: 22
#   c: 23 - s: 8
#   c: 26 - s: 19
#   c: 32 - s: 27
# total attemps:  333
#
#   c: 8 - s: 12
#   c: 11 - s: 57
#   c: 15 - s: 6
#   c: 16 - s: 7
#   c: 22 - s: 23
#   c: 27 - s: 31
#   c: 31 - s: 7
#   c: 33 - s: 3
#   c: 34 - s: 6
#   c: 35 - s: 12
# total attemps:  334
#
#   c: 12 - s: 30
#   c: 18 - s: 6
#   c: 19 - s: 12
#   c: 21 - s: 6
#   c: 34 - s: 11
# total attemps:  335
#
#   c: 11 - s: 17
#   c: 14 - s: 25
#   c: 17 - s: 50
#   c: 18 - s: 50
# total attemps:  336
#
#   c: 2 - s: 6
#   c: 9 - s: 4
#   c: 12 - s: 7
#   c: 14 - s: 19
#   c: 15 - s: 12
#   c: 21 - s: 9
#   c: 23 - s: 8
#   c: 24 - s: 46
#   c: 31 - s: 4
#   c: 32 - s: 11
#   c: 34 - s: 8
# total attemps:  337
#
#   c: 6 - s: 28
#   c: 14 - s: 14
# total attemps:  338
#
#   c: 6 - s: 8
#   c: 7 - s: 2
#   c: 9 - s: 5
#   c: 12 - s: 27
#   c: 14 - s: 23
#   c: 20 - s: 21
#   c: 25 - s: 36
#   c: 27 - s: 5
#   c: 33 - s: 15
#   c: 34 - s: 12
#   c: 35 - s: 16
# total attemps:  339
#
#   c: 0 - s: 15
#   c: 2 - s: 14
#   c: 6 - s: 7
#   c: 7 - s: 3
#   c: 25 - s: 39
# total attemps:  340
#
#   c: 13 - s: 9
#   c: 18 - s: 21
#   c: 23 - s: 16
#   c: 35 - s: 47
# total attemps:  341
#
#   c: 1 - s: 38
#   c: 8 - s: 30
#   c: 24 - s: 10
#   c: 28 - s: 57
#   c: 29 - s: 3
#   c: 31 - s: 34
#   c: 35 - s: 22
# total attemps:  342
#
#   c: 0 - s: 49
#   c: 5 - s: 3
#   c: 6 - s: 9
#   c: 10 - s: 4
#   c: 14 - s: 3
#   c: 18 - s: 41
#   c: 23 - s: 4
#   c: 29 - s: 7
#   c: 30 - s: 4
#   c: 32 - s: 20
#   c: 34 - s: 36
# total attemps:  343
#
#   c: 17 - s: 20
#   c: 27 - s: 23
#   c: 31 - s: 4
# total attemps:  344
#
#   c: 14 - s: 32
#   c: 18 - s: 8
#   c: 23 - s: 12
#   c: 30 - s: 41
#   c: 34 - s: 45
# total attemps:  345
#
#   c: 0 - s: 28
#   c: 4 - s: 12
#   c: 5 - s: 51
#   c: 13 - s: 5
#   c: 15 - s: 45
#   c: 18 - s: 20
#   c: 19 - s: 29
#   c: 21 - s: 29
#   c: 23 - s: 51
#   c: 25 - s: 22
#   c: 26 - s: 15
#   c: 28 - s: 20
#   c: 32 - s: 34
#   c: 33 - s: 30
#   c: 35 - s: 57
# total attemps:  346
#
#   c: 7 - s: 30
#   c: 11 - s: 7
#   c: 17 - s: 12
#   c: 20 - s: 57
#   c: 24 - s: 4
#   c: 27 - s: 6
#   c: 35 - s: 26
# total attemps:  347
#
#   c: 4 - s: 37
#   c: 13 - s: 27
#   c: 14 - s: 19
#   c: 18 - s: 8
#   c: 24 - s: 7
#   c: 25 - s: 45
#   c: 26 - s: 10
#   c: 28 - s: 18
#   c: 30 - s: 5
# total attemps:  348
#
#   c: 29 - s: 26
#   c: 31 - s: 8
#   c: 32 - s: 19
# total attemps:  349
#
#   c: 13 - s: 37
#   c: 21 - s: 51
#   c: 22 - s: 9
#   c: 23 - s: 5
#   c: 26 - s: 25
#   c: 29 - s: 52
#   c: 32 - s: 47
#   c: 34 - s: 6
# total attemps:  350
#
#   c: 0 - s: 3
#   c: 2 - s: 39
#   c: 7 - s: 22
#   c: 9 - s: 15
#   c: 12 - s: 7
#   c: 14 - s: 45
#   c: 16 - s: 13
#   c: 19 - s: 9
#   c: 22 - s: 30
#   c: 26 - s: 4
#   c: 27 - s: 24
#   c: 30 - s: 29
#   c: 31 - s: 29
#   c: 35 - s: 13
# total attemps:  351
#
#   c: 0 - s: 31
#   c: 1 - s: 7
#   c: 7 - s: 4
#   c: 9 - s: 7
#   c: 10 - s: 15
#   c: 11 - s: 45
#   c: 20 - s: 21
#   c: 21 - s: 46
#   c: 22 - s: 55
#   c: 27 - s: 25
#   c: 30 - s: 5
#   c: 34 - s: 11
# total attemps:  352
#
#   c: 16 - s: 6
#   c: 22 - s: 9
# total attemps:  353
#
#   c: 0 - s: 13
#   c: 2 - s: 26
#   c: 8 - s: 4
#   c: 11 - s: 16
#   c: 21 - s: 7
#   c: 23 - s: 3
#   c: 24 - s: 5
#   c: 26 - s: 11
#   c: 30 - s: 10
#   c: 33 - s: 48
# total attemps:  354
#
#   c: 0 - s: 59
#   c: 9 - s: 6
#   c: 13 - s: 24
#   c: 24 - s: 24
#   c: 26 - s: 14
#   c: 29 - s: 5
#   c: 32 - s: 15
#   c: 34 - s: 9
# total attemps:  355
#
#   c: 9 - s: 4
#   c: 14 - s: 13
#   c: 16 - s: 9
#   c: 17 - s: 5
#   c: 21 - s: 5
#   c: 22 - s: 13
#   c: 25 - s: 6
#   c: 26 - s: 4
#   c: 27 - s: 3
#   c: 33 - s: 21
# total attemps:  356
#
#   c: 6 - s: 30
#   c: 12 - s: 35
#   c: 17 - s: 4
#   c: 20 - s: 53
#   c: 21 - s: 10
#   c: 22 - s: 36
#   c: 24 - s: 23
#   c: 31 - s: 5
#   c: 33 - s: 37
#   c: 34 - s: 55
# total attemps:  357
#
#   c: 2 - s: 9
#   c: 3 - s: 31
#   c: 12 - s: 17
#   c: 15 - s: 8
#   c: 24 - s: 3
#   c: 25 - s: 17
#   c: 26 - s: 12
#   c: 30 - s: 37
#   c: 33 - s: 12
#   c: 34 - s: 9
# total attemps:  358
#
#   c: 4 - s: 14
#   c: 7 - s: 4
#   c: 10 - s: 27
#   c: 13 - s: 12
#   c: 14 - s: 50
#   c: 16 - s: 56
#   c: 17 - s: 35
# total attemps:  359
#
#   c: 0 - s: 3
#   c: 21 - s: 29
#   c: 22 - s: 15
# total attemps:  360
#
#   c: 8 - s: 27
#   c: 9 - s: 16
#   c: 12 - s: 49
#   c: 15 - s: 6
#   c: 19 - s: 4
#   c: 22 - s: 5
#   c: 28 - s: 22
#   c: 32 - s: 29
#   c: 35 - s: 27
# total attemps:  361
#
#   c: 21 - s: 10
#   c: 23 - s: 12
#   c: 26 - s: 33
# total attemps:  362
#
#   c: 2 - s: 16
#   c: 20 - s: 33
#   c: 27 - s: 46
#   c: 29 - s: 56
# total attemps:  363
#
#   c: 0 - s: 17
#   c: 3 - s: 13
#   c: 10 - s: 2
#   c: 11 - s: 44
#   c: 13 - s: 12
#   c: 14 - s: 5
#   c: 17 - s: 6
#   c: 18 - s: 19
#   c: 19 - s: 9
#   c: 22 - s: 9
#   c: 24 - s: 14
#   c: 25 - s: 50
#   c: 28 - s: 4
#   c: 32 - s: 5
#   c: 33 - s: 26
# total attemps:  364
#
#   c: 6 - s: 28
#   c: 11 - s: 41
#   c: 15 - s: 8
#   c: 19 - s: 7
#   c: 22 - s: 44
#   c: 28 - s: 4
#   c: 31 - s: 8
# total attemps:  365
#
#   c: 13 - s: 19
#   c: 21 - s: 16
#   c: 23 - s: 16
#   c: 25 - s: 7
#   c: 27 - s: 10
#   c: 28 - s: 26
#   c: 29 - s: 21
#   c: 33 - s: 13
#   c: 35 - s: 5
# total attemps:  366
#
#   c: 0 - s: 30
#   c: 14 - s: 26
#   c: 16 - s: 7
#   c: 28 - s: 40
#   c: 33 - s: 55
# total attemps:  367
#
#   c: 0 - s: 16
#   c: 11 - s: 3
#   c: 13 - s: 7
#   c: 15 - s: 6
#   c: 22 - s: 50
#   c: 25 - s: 30
#   c: 32 - s: 34
#   c: 35 - s: 19
# total attemps:  368
#
#   c: 19 - s: 43
#   c: 21 - s: 12
#   c: 24 - s: 34
#   c: 26 - s: 3
#   c: 28 - s: 9
#   c: 29 - s: 6
#   c: 30 - s: 44
#   c: 34 - s: 55
# total attemps:  369
#
#   c: 33 - s: 38
#   c: 35 - s: 34
# total attemps:  370
#
#   c: 14 - s: 53
#   c: 15 - s: 26
#   c: 23 - s: 18
#   c: 27 - s: 3
#   c: 30 - s: 15
#   c: 32 - s: 31
#   c: 34 - s: 1
# total attemps:  371
#
#   c: 11 - s: 17
#   c: 19 - s: 7
#   c: 22 - s: 8
#   c: 31 - s: 52
#   c: 33 - s: 3
# total attemps:  372
#
#   c: 24 - s: 35
#   c: 27 - s: 39
# total attemps:  373
#
#   c: 0 - s: 32
#   c: 18 - s: 45
#   c: 26 - s: 7
#   c: 29 - s: 21
# total attemps:  374
#
#   c: 16 - s: 6
#   c: 28 - s: 37
#   c: 31 - s: 11
# total attemps:  375
#
#   c: 15 - s: 27
#   c: 19 - s: 36
#   c: 20 - s: 25
#   c: 27 - s: 36
#   c: 28 - s: 29
#   c: 29 - s: 6
#   c: 31 - s: 14
#   c: 32 - s: 17
#   c: 34 - s: 36
#   c: 35 - s: 24
# total attemps:  376
#
#   c: 0 - s: 31
#   c: 9 - s: 17
#   c: 10 - s: 21
#   c: 14 - s: 6
#   c: 16 - s: 11
#   c: 17 - s: 7
#   c: 22 - s: 2
#   c: 23 - s: 2
#   c: 24 - s: 23
#   c: 25 - s: 34
#   c: 29 - s: 4
#   c: 31 - s: 6
# total attemps:  377
#
#   c: 3 - s: 30
#   c: 7 - s: 3
#   c: 8 - s: 4
#   c: 9 - s: 23
#   c: 11 - s: 5
#   c: 13 - s: 21
#   c: 20 - s: 28
#   c: 26 - s: 11
#   c: 27 - s: 4
#   c: 33 - s: 14
#   c: 34 - s: 11
# total attemps:  378
#
#   c: 0 - s: 9
#   c: 4 - s: 25
#   c: 6 - s: 5
#   c: 11 - s: 6
#   c: 14 - s: 5
#   c: 16 - s: 8
#   c: 24 - s: 37
#   c: 26 - s: 19
#   c: 27 - s: 3
#   c: 32 - s: 19
#   c: 35 - s: 22
# total attemps:  379
#
#   c: 1 - s: 17
#   c: 11 - s: 17
#   c: 18 - s: 41
#   c: 33 - s: 28
#   c: 35 - s: 28
# total attemps:  380
#
#   c: 9 - s: 14
#   c: 10 - s: 6
#   c: 13 - s: 46
#   c: 20 - s: 8
#   c: 21 - s: 19
#   c: 24 - s: 4
#   c: 26 - s: 5
#   c: 28 - s: 17
#   c: 34 - s: 4
# total attemps:  381
#
#   c: 14 - s: 5
#   c: 35 - s: 18
# total attemps:  382
#
#   c: 12 - s: 43
#   c: 17 - s: 12
#   c: 22 - s: 39
#   c: 28 - s: 7
#   c: 33 - s: 11
#   c: 35 - s: 28
# total attemps:  383
#
#   c: 2 - s: 22
#   c: 10 - s: 19
#   c: 17 - s: 22
#   c: 18 - s: 7
#   c: 20 - s: 42
#   c: 23 - s: 10
#   c: 25 - s: 14
#   c: 30 - s: 20
#   c: 31 - s: 26
#   c: 33 - s: 37
#   c: 35 - s: 10
# total attemps:  384
#
#   c: 3 - s: 54
#   c: 9 - s: 8
#   c: 32 - s: 6
#   c: 33 - s: 41
# total attemps:  385
#
#   c: 4 - s: 57
#   c: 9 - s: 16
#   c: 11 - s: 19
#   c: 13 - s: 57
#   c: 17 - s: 10
#   c: 22 - s: 2
#   c: 25 - s: 51
#   c: 29 - s: 38
#   c: 33 - s: 13
#   c: 35 - s: 8
# total attemps:  386
#
#   c: 21 - s: 21
#   c: 28 - s: 13
#   c: 30 - s: 56
#   c: 34 - s: 16
#   c: 35 - s: 16
# total attemps:  387
#
#   c: 1 - s: 49
#   c: 5 - s: 23
#   c: 6 - s: 5
#   c: 8 - s: 27
#   c: 9 - s: 3
#   c: 12 - s: 32
#   c: 15 - s: 52
#   c: 17 - s: 10
#   c: 23 - s: 7
#   c: 24 - s: 6
#   c: 26 - s: 3
#   c: 27 - s: 27
#   c: 30 - s: 10
#   c: 34 - s: 8
#   c: 35 - s: 9
# total attemps:  388
#
#   c: 1 - s: 22
#   c: 13 - s: 33
#   c: 24 - s: 7
#   c: 34 - s: 30
# total attemps:  389
#
#   c: 9 - s: 14
#   c: 20 - s: 7
#   c: 22 - s: 28
#   c: 23 - s: 6
# total attemps:  390
#
#   c: 3 - s: 5
#   c: 6 - s: 10
#   c: 8 - s: 8
#   c: 14 - s: 41
#   c: 19 - s: 3
#   c: 21 - s: 3
#   c: 27 - s: 6
#   c: 28 - s: 27
#   c: 29 - s: 21
#   c: 31 - s: 20
#   c: 35 - s: 28
# total attemps:  391
#
#   c: 4 - s: 18
#   c: 5 - s: 5
#   c: 9 - s: 20
#   c: 13 - s: 20
#   c: 14 - s: 6
#   c: 16 - s: 11
#   c: 24 - s: 58
#   c: 25 - s: 8
#   c: 31 - s: 11
#   c: 35 - s: 24
# total attemps:  392
#
#   c: 0 - s: 8
#   c: 1 - s: 11
#   c: 12 - s: 4
#   c: 15 - s: 9
#   c: 20 - s: 48
#   c: 31 - s: 41
#   c: 33 - s: 16
# total attemps:  393
#
#   c: 5 - s: 6
#   c: 10 - s: 15
#   c: 16 - s: 5
#   c: 25 - s: 7
#   c: 28 - s: 7
#   c: 30 - s: 3
#   c: 34 - s: 37
# total attemps:  394
#
#   c: 2 - s: 4
#   c: 32 - s: 45
# total attemps:  395
#
#   c: 6 - s: 3
#   c: 10 - s: 9
#   c: 15 - s: 59
#   c: 21 - s: 10
#   c: 22 - s: 30
#   c: 24 - s: 45
#   c: 26 - s: 33
#   c: 29 - s: 15
#   c: 30 - s: 5
# total attemps:  396
#
#   c: 4 - s: 53
#   c: 16 - s: 10
#   c: 21 - s: 43
#   c: 30 - s: 23
#   c: 31 - s: 50
# total attemps:  397
#
#   c: 11 - s: 4
#   c: 15 - s: 36
#   c: 25 - s: 47
#   c: 28 - s: 12
#   c: 29 - s: 27
#   c: 31 - s: 4
#   c: 33 - s: 20
#   c: 35 - s: 15
# total attemps:  398
#
#   c: 11 - s: 3
#   c: 16 - s: 19
#   c: 23 - s: 20
#   c: 24 - s: 12
#   c: 30 - s: 13
#   c: 31 - s: 5
# total attemps:  399
#
#   c: 12 - s: 7
#   c: 16 - s: 11
#   c: 19 - s: 25
#   c: 28 - s: 36
#   c: 29 - s: 5
#   c: 31 - s: 27
# total attemps:  400
#
#   c: 0 - s: 49
#   c: 4 - s: 23
#   c: 6 - s: 16
#   c: 7 - s: 51
#   c: 15 - s: 3
#   c: 18 - s: 6
#   c: 19 - s: 7
#   c: 20 - s: 8
#   c: 22 - s: 4
#   c: 25 - s: 57
#   c: 27 - s: 33
# total attemps:  401
#
#   c: 21 - s: 18
#   c: 34 - s: 37
# total attemps:  402
#
#   c: 23 - s: 38
# total attemps:  403
#
#   c: 2 - s: 43
#   c: 7 - s: 33
#   c: 11 - s: 6
#   c: 16 - s: 3
#   c: 18 - s: 13
#   c: 22 - s: 26
#   c: 25 - s: 17
#   c: 26 - s: 3
#   c: 27 - s: 5
#   c: 28 - s: 10
#   c: 29 - s: 4
#   c: 33 - s: 16
#   c: 35 - s: 3
# total attemps:  404
#
#   c: 8 - s: 4
#   c: 10 - s: 15
#   c: 13 - s: 6
#   c: 17 - s: 5
#   c: 19 - s: 6
#   c: 20 - s: 4
#   c: 22 - s: 9
#   c: 27 - s: 30
#   c: 29 - s: 12
#   c: 33 - s: 22
# total attemps:  405
#
#   c: 15 - s: 5
#   c: 32 - s: 42
# total attemps:  406
#
#   c: 4 - s: 40
#   c: 6 - s: 34
#   c: 11 - s: 17
#   c: 13 - s: 14
#   c: 14 - s: 21
#   c: 16 - s: 33
#   c: 17 - s: 18
#   c: 19 - s: 12
#   c: 21 - s: 12
#   c: 27 - s: 15
#   c: 29 - s: 9
#   c: 31 - s: 11
#   c: 33 - s: 7
# total attemps:  407
#
#   c: 3 - s: 9
#   c: 6 - s: 5
#   c: 12 - s: 5
#   c: 18 - s: 39
#   c: 22 - s: 59
#   c: 28 - s: 4
#   c: 35 - s: 8
# total attemps:  408
#
#   c: 3 - s: 5
#   c: 7 - s: 4
#   c: 10 - s: 6
#   c: 19 - s: 46
#   c: 24 - s: 9
#   c: 25 - s: 38
#   c: 30 - s: 12
#   c: 31 - s: 47
#   c: 33 - s: 41
#   c: 34 - s: 52
#   c: 35 - s: 9
# total attemps:  409
#
#   c: 10 - s: 10
#   c: 18 - s: 4
#   c: 24 - s: 6
#   c: 27 - s: 7
#   c: 31 - s: 18
#   c: 33 - s: 10
# total attemps:  410
#
#   c: 1 - s: 21
#   c: 11 - s: 59
#   c: 21 - s: 49
#   c: 23 - s: 11
#   c: 24 - s: 7
#   c: 30 - s: 23
#   c: 31 - s: 13
# total attemps:  411
#
#   c: 0 - s: 33
#   c: 21 - s: 11
#   c: 27 - s: 22
# total attemps:  412
#
#   c: 9 - s: 21
#   c: 15 - s: 39
#   c: 18 - s: 7
#   c: 19 - s: 49
#   c: 24 - s: 6
#   c: 26 - s: 22
# total attemps:  413
#
#   c: 3 - s: 53
#   c: 13 - s: 21
#   c: 29 - s: 47
# total attemps:  414
#
#   c: 11 - s: 13
#   c: 12 - s: 14
#   c: 13 - s: 8
#   c: 18 - s: 26
#   c: 21 - s: 17
# total attemps:  415
#
#   c: 7 - s: 8
#   c: 9 - s: 3
#   c: 11 - s: 17
#   c: 13 - s: 24
#   c: 17 - s: 3
#   c: 18 - s: 22
#   c: 23 - s: 17
#   c: 28 - s: 7
#   c: 33 - s: 49
# total attemps:  416
#
#   c: 9 - s: 3
#   c: 11 - s: 7
#   c: 17 - s: 16
#   c: 18 - s: 38
#   c: 21 - s: 58
#   c: 28 - s: 3
#   c: 29 - s: 10
#   c: 30 - s: 27
#   c: 31 - s: 19
# total attemps:  417
#
# total attemps:  418

# %%
print(pred.KMA)
# Out:
# <xarray.Dataset>
# Dimensions:           (n_clusters: 36, n_components: 14590, n_features: 97)
# Dimensions without coordinates: n_clusters, n_components, n_features
# Data variables:
#     bmus              (n_components) int32 27 27 27 20 27 27 ... 22 22 25 25 26
#     cenEOFs           (n_clusters, n_features) float64 0.7175 ... -0.2374
#     centroids         (n_clusters, n_features) float64 15.81 -10.26 ... 3.263
#     group_size        (n_clusters) int64 382 102 120 392 844 ... 265 285 861 134
#     sorted_order      (n_clusters) int32 19 9 2 24 5 10 1 ... 30 34 13 25 26 8
#     sorted_bmus       (n_components) int32 23 23 23 14 23 23 ... 10 10 33 33 34
#     sorted_cenEOFs    (n_clusters, n_features) float64 0.06095 0.2052 ... 0.3252
#     sorted_centroids  (n_clusters, n_features) float64 2.305 4.243 ... 4.341
#     time              (n_components) datetime64[ns] 1979-01-21 ... 2018-12-31
# Attributes:
#     method:   regression guided
#     alpha:    0.3

# %%
## if you've already run the KMA classification 

# Use our custom ESTELA Predictor 
pred = Predictor(db.paths.site.ESTELA.pred_slp)

# Load predictor PCA, KMA
pred.Load()

# %%
# Plot DWTs (data mean)
pred.Plot_DWTs('SLP', kind='mean', show=True);

# %%
# Plot DWTs (data anomalies)
pred.Plot_DWTs('SLP', kind='anom', show=True);

# %%
# Plot DWTs Probabilities
pred.Plot_DWTs_Probs();

# %%
# Plot PC1, PC2, PC3 (3D)
pred.Plot_PCs_3D();

# %%
# Plot PCs DWT centroids
pred.Plot_DWT_PCs(n=6);

# %% [markdown]
# ## ESTELA Predictor - Add Historical TCs

# %%
# --------------------------------------
# use historical storms-parameters inside r1 to modify predictor KMA results 

storm_dates = np.empty(0)
storm_categs = np.empty(0)

# add r1 storms to predictor KMA
pred.Mod_KMA_AddStorms(storm_dates, storm_categs)

# %%
print(pred.KMA)
# Out:
# <xarray.Dataset>
# Dimensions:             (n_clusters: 36, n_components: 14590, n_features: 97)
# Dimensions without coordinates: n_clusters, n_components, n_features
# Data variables:
#     bmus                (n_components) int32 ...
#     cenEOFs             (n_clusters, n_features) float64 ...
#     centroids           (n_clusters, n_features) float64 ...
#     group_size          (n_clusters) int64 ...
#     sorted_order        (n_clusters) int32 ...
#     sorted_bmus         (n_components) int32 23 23 23 14 23 ... 10 10 33 33 34
#     sorted_cenEOFs      (n_clusters, n_features) float64 ...
#     sorted_centroids    (n_clusters, n_features) float64 ...
#     time                (n_components) datetime64[ns] 1979-01-21 ... 2018-12-31
#     sorted_bmus_storms  (n_components) int32 23 23 23 14 23 ... 10 10 33 33 34
# Attributes:
#     method:   regression guided
#     alpha:    0.3

# %%
# Plot DWTs Probabilities with updated bmus
pred.Plot_DWTs_Probs(field='sorted_bmus_storms', n_clusters=42);

# %%
# --------------------------------------
# Calculate intradaily MU TAU hydrographs

l_MU_TAU = pred.Calc_MU_TAU_Hydrographs(WAVES)

# store hydrographs MU TAU
db.Save_MU_TAU_hydrograms(l_MU_TAU)

# %%
# Plot MJO phases / DWTs Probabilities 

# num. MJO phases and DWTs
MJO_ncs = 8
DWT_ncs = 36

# MJO, DWTs historical data
MJO_hist, DWT_hist = db.Load_MJO_DWTs_Plots_hist()

# categories to plot
MJO_phase = MJO_hist.phase.values[:]
DWT_bmus =  DWT_hist.bmus.values[:]

Plot_Probs_WT_WT(
    MJO_phase, DWT_bmus, MJO_ncs, DWT_ncs,
    wt_colors=False, ttl='DWTs Probabilities by MJO Phases (Historical)');


# plot DWTs conditional probabilities to each MJO, minus mean probabilities
Plot_Probs_WT_WT_anomaly(
    MJO_phase, DWT_bmus, MJO_ncs, DWT_ncs,
    wt_colors=False, ttl = 'DWTs anomaly Probabilities by MJO Phases (Historical)'
);

# %%
# Plot Waves Families by DWTs

# DWTs bmus
DWTs = pred.KMA
BMUS = xr.Dataset(
    {'bmus':(('time',), DWTs['sorted_bmus_storms'].values[:])},
    coords = {'time': DWTs.time.values[:]}
)
n_clusters = 42

# common dates
dates_common= xds_common_dates_daily([WAVES_d, DWTs])

# waves and bmus at common dates
WAVES_sel = WAVES_d.sel(time=dates_common)
bmus_sel = BMUS.sel(time=dates_common).bmus.values[:]

# Plot Waves Families by DWTs
Plot_Waves_DWTs(WAVES_sel, bmus_sel, n_clusters);

# %%
# Plot DWT data population by families
Plot_DWTs_FamiliesPopulation(WAVES_sel, bmus_sel, n_clusters);
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ##  Code cell below will kill the running kernel so that the next notebook can operate correctly.

# %%
import signal

# Get the current process ID (which is the kernel's process ID in this context)
pid = os.getpid()

# Send the SIGTERM signal to the current process
os.kill(pid, signal.SIGTERM)
